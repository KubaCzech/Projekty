# %% [markdown]
#  ## Feature Selection
#
#  In real life applications, it's rare to have all of the features useful for building a data mining model. It's important to remove redundant or non-informative features from the dataset. First and foremost, the more the features are incorporated into the model, the more complicated the model becomes. If we're adding redundant or non-informative features to the equation, we increase the processing power demand, which very often is already pretty high. In some rare cases, the less useful features reduce the accuracy of the model (it depends on the used techniques, very often that's not the case). Nonetheless feature selection is one of the core processes, next to the data normalization and feature engineering, applied to the data prior to perfmorming the actual data mining techniques. This notebook covers the commonly used Feature Selection techniques, which are a part of the sklearn feature_selection module. Let's start by importing the modules to the nodebook.

# %%
from sklearn import datasets, preprocessing, feature_selection
from itertools import compress

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset

# %% [markdown]
# In this excercise we will use the [Wine](https://archive.ics.uci.edu/ml/datasets/wine) dataset available in the `scikit-learn` library. After loading the dataset display its description and familiarize yourself with the interpretation of features.

# %%
wine = datasets.load_wine()

print(wine.DESCR)

print('Data shape: ', wine.data.shape)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 178
# :Number of Attributes: 13 numeric, predictive attributes and the class
# :Attribute Information:
#     - Alcohol
#     - Malic acid
#     - Ash
#     - Alcalinity of ash
#     - Magnesium
#     - Total phenols
#     - Flavanoids
#     - Nonflavanoid phenols
#     - Proanthocyanins
#     - Color intensity
#     - Hue
#     - OD280/OD315 of diluted wines
#     - Proline
#     - class:
#         - class_0
#         - class_1
#         - class_2
#
# :Summary Statistics:
#
# ============================= ==== ===== ======= =====
#                                 Min   Max   Mean     SD
# ============================= ==== ===== ======= =====
# Alcohol:                      11.0  14.8    13.0   0.8
# Malic Acid:                   0.74  5.80    2.34  1.12
# Ash:                          1.36  3.23    2.36  0.27
# Alcalinity of Ash:            10.6  30.0    19.5   3.3
# Magnesium:                    70.0 162.0    99.7  14.3
# Total Phenols:                0.98  3.88    2.29  0.63
# Flavanoids:                   0.34  5.08    2.03  1.00
# Nonflavanoid Phenols:         0.13  0.66    0.36  0.12
# Proanthocyanins:              0.41  3.58    1.59  0.57
# Colour Intensity:              1.3  13.0     5.1   2.3
# Hue:                          0.48  1.71    0.96  0.23
# OD280/OD315 of diluted wines: 1.27  4.00    2.61  0.71
# Proline:                       278  1680     746   315
# ============================= ==== ===== ======= =====
#
# :Missing Attribute Values: None
# :Class Distribution: class_0 (59), class_1 (71), class_2 (48)
# :Creator: R.A. Fisher
# :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
# :Date: July, 1988
#
# This is a copy of UCI ML Wine recognition datasets.
# https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data
#
# The data is the results of a chemical analysis of wines grown in the same
# region in Italy by three different cultivators. There are thirteen different
# measurements taken for different constituents found in the three types of
# wine.
#
# Original Owners:
#
# Forina, M. et al, PARVUS -
# An Extendible Package for Data Exploration, Classification and Correlation.
# Institute of Pharmaceutical and Food Analysis and Technologies,
# Via Brigata Salerno, 16147 Genoa, Italy.
#
# Citation:
#
# Lichman, M. (2013). UCI Machine Learning Repository
# [https://archive.ics.uci.edu/ml]. Irvine, CA: University of California,
# School of Information and Computer Science.
#
# |details-start|
# **References**
# |details-split|
#
# (1) S. Aeberhard, D. Coomans and O. de Vel,
# Comparison of Classifiers in High Dimensional Settings,
# Tech. Rep. no. 92-02, (1992), Dept. of Computer Science and Dept. of
# Mathematics and Statistics, James Cook University of North Queensland.
# (Also submitted to Technometrics).
#
# The data was used with many others for comparing various
# classifiers. The classes are separable, though only RDA
# has achieved 100% correct classification.
# (RDA : 100%, QDA 99.4%, LDA 98.9%, 1NN 96.1% (z-transformed data))
# (All results using the leave-one-out technique)
#
# (2) S. Aeberhard, D. Coomans and O. de Vel,
# "THE CLASSIFICATION PERFORMANCE OF RDA"
# Tech. Rep. no. 92-01, (1992), Dept. of Computer Science and Dept. of
# Mathematics and Statistics, James Cook University of North Queensland.
# (Also submitted to Journal of Chemometrics).
#
# |details-end|
#
# Data shape:  (178, 13)

# %% [markdown]
# Let's prepare a dataframe for the wine dataset.

# %%
wine_dataframe = pd.DataFrame(wine.data,columns = wine.feature_names)
wine_dataframe
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %% [markdown]
# ## Removing attributes with low variance

# %% [markdown]
# Obviously, the features which share very similar values across the entire dataset are not going to be useful. We can remove those variables with a tool, which is called [VarianceThreshold](http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.VarianceThreshold.html#sklearn.feature_selection.VarianceThreshold). Prior to applying this tool let's check the variance of each feature.

# %%
wine_dataframe.std()**2
# Out:
# alcohol                             0.659062
# malic_acid                          1.248015
# ash                                 0.075265
# alcalinity_of_ash                  11.152686
# magnesium                         203.989335
# total_phenols                       0.391690
# flavanoids                          0.997719
# nonflavanoid_phenols                0.015489
# proanthocyanins                     0.327595
# color_intensity                     5.374449
# hue                                 0.052245
# od280/od315_of_diluted_wines        0.504086
# proline                         99166.717355
# dtype: float64

# %% [markdown]
# We can now observe the importance of normalization. Obviously, the values of the `magnesium` feature are a few orders of magnitude higher than the values of the `hue` feature. The default, most common setting of the variance threshold method gets rid of the features, which have a variance of 0 (all of the values are the same across the entire dataset). If however we wanted to apply this method with a custom threshold we need to perform some kind of normalization scheme. Let's start with standarization.

# %%
#we import standarizer
from sklearn.preprocessing import StandardScaler

#initialize it
scaler = StandardScaler()
#calculate all the necessary data to perform the standarization
scaler.fit(wine_dataframe)
#apply the standarizer to the data
wine_dataframe_standarized = pd.DataFrame(scaler.transform(wine_dataframe),columns = wine.feature_names)
wine_dataframe_standarized.std()**2
# Out:
# alcohol                         1.00565
# malic_acid                      1.00565
# ash                             1.00565
# alcalinity_of_ash               1.00565
# magnesium                       1.00565
# total_phenols                   1.00565
# flavanoids                      1.00565
# nonflavanoid_phenols            1.00565
# proanthocyanins                 1.00565
# color_intensity                 1.00565
# hue                             1.00565
# od280/od315_of_diluted_wines    1.00565
# proline                         1.00565
# dtype: float64

# %% [markdown]
# In that case the custom Variance Threshold wouldn't make much sense either. After all the standarization process has normalized the variance for each of the features. Let's take a look at min-max normalzation.

# %%
#we import normalizer
from sklearn.preprocessing import MinMaxScaler

#initialize it
scaler = MinMaxScaler()
#calculate all the necessary data to perform the normalization
scaler.fit(wine_dataframe)
#apply the standarizer to the data
wine_dataframe_normalized = pd.DataFrame(scaler.transform(wine_dataframe),columns = wine.feature_names)
wine_dataframe_normalized.std()**2
# Out:
# alcohol                         0.045641
# malic_acid                      0.048744
# ash                             0.021523
# alcalinity_of_ash               0.029633
# magnesium                       0.024101
# total_phenols                   0.046574
# flavanoids                      0.044407
# nonflavanoid_phenols            0.055139
# proanthocyanins                 0.032600
# color_intensity                 0.039127
# hue                             0.034533
# od280/od315_of_diluted_wines    0.067636
# proline                         0.050451
# dtype: float64

# %% [markdown]
# As you can see all of the variables have relatively low variance, but by no means niether of them have a close to zero variance. We can compare the variables by their variance, but a raw threshold should be used only for near zero or zero variance features. Here's how we can apply the tool to the data. In this example the threshold is set to 0.03, just to show how the method works. In fact, here we shouldn't remove any of the features, as the variance is way too high.

# %%
from sklearn.feature_selection import VarianceThreshold
#we create a variance threshold object
sel = VarianceThreshold(threshold=0.03)
#we apply the method to the data - this method does not create a new dataframe, just a numpy array
wine_variance_removed = sel.fit_transform(wine_dataframe_normalized)
#we can create a new dataframe using the get_feature_names_out() function to get the names of the selected columns
wine_dataframe_variance_removed = pd.DataFrame(wine_variance_removed, columns = sel.get_feature_names_out())
wine_dataframe_variance_removed
# Out:
#       alcohol  malic_acid  total_phenols  flavanoids  nonflavanoid_phenols  \
# 0    0.842105    0.191700       0.627586    0.573840              0.283019
# 1    0.571053    0.205534       0.575862    0.510549              0.245283
# 2    0.560526    0.320158       0.627586    0.611814              0.320755
# 3    0.878947    0.239130       0.989655    0.664557              0.207547
# 4    0.581579    0.365613       0.627586    0.495781              0.490566
# ..        ...         ...            ...         ...                   ...
# 173  0.705263    0.970356       0.241379    0.056962              0.735849
# 174  0.623684    0.626482       0.282759    0.086498              0.566038
# 175  0.589474    0.699605       0.210345    0.073840              0.566038
# 176  0.563158    0.365613       0.231034    0.071730              0.754717
# 177  0.815789    0.664032       0.368966    0.088608              0.811321
#
#      proanthocyanins  color_intensity       hue  od280/od315_of_diluted_wines  \
# 0           0.593060         0.372014  0.455285                      0.970696
# 1           0.274448         0.264505  0.463415                      0.780220
# 2           0.757098         0.375427  0.447154                      0.695971
# 3           0.558360         0.556314  0.308943                      0.798535
# 4           0.444795         0.259386  0.455285                      0.608059
# ..               ...              ...       ...                           ...
# 173         0.205047         0.547782  0.130081                      0.172161
# 174         0.315457         0.513652  0.178862                      0.106227
# 175         0.296530         0.761092  0.089431                      0.106227
# 176         0.331230         0.684300  0.097561                      0.128205
# 177         0.296530         0.675768  0.105691                      0.120879
#
#       proline
# 0    0.561341
# 1    0.550642
# 2    0.646933
# 3    0.857347
# 4    0.325963
# ..        ...
# 173  0.329529
# 174  0.336662
# 175  0.397290
# 176  0.400856
# 177  0.201141
#
# [178 rows x 10 columns]

# %% [markdown]
# We can also see, which features should be removed with the get_support() function.

# %%
sel.get_support()
# Out:
# array([ True,  True, False, False, False,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %% [markdown]
# ## Select k best features
#
# You probably saw that we can rank the features using the variance. In fact it's a common practice to rank the features. If it is necesseary to reduce complexity of the model, we can pick the variables, which have the best scores. Before we go to the code, let's go trough the ranking functions. The ranking functions can be divided into two classes:
#   - unsupervised - the ranking score is calculated with use of the statistical information:
#        - Variance - it is used to remove features, which do not yield any information
#        - Correlation - it is used to remove features, which are redundant
#
#   - supervised - in this case, the ranking score is related to the usefulness of the feature in the context of discovering the target values (e.g. how useful would be that feature if we applied linear regression to discover the target value):
#
#      - Chi-squared score ([chi2](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.chi2.html#sklearn.feature_selection.chi2))
#      - ANOVA score ([f_classif](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.f_classif.html#sklearn.feature_selection.f_classif))
#      - Information Gain ([mutual_info_classif](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.mutual_info_classif.html#sklearn.feature_selection.mutual_info_classif))
#      - Linear Regression f-value ([f_regression](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.f_regression.html#sklearn.feature_selection.f_regression))
#
# We have already investiaged the Variance. Let's take a look at correlation. Calculating correlation is as simple as calling the [corr()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html) function on the pandas dataframe.

# %%
wine_dataframe_normalized.corr()
# Out:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
#
#                               alcalinity_of_ash  magnesium  total_phenols  \
# alcohol                               -0.310235   0.270798       0.289101
# malic_acid                             0.288500  -0.054575      -0.335167
# ash                                    0.443367   0.286587       0.128980
# alcalinity_of_ash                      1.000000  -0.083333      -0.321113
# magnesium                             -0.083333   1.000000       0.214401
# total_phenols                         -0.321113   0.214401       1.000000
# flavanoids                            -0.351370   0.195784       0.864564
# nonflavanoid_phenols                   0.361922  -0.256294      -0.449935
# proanthocyanins                       -0.197327   0.236441       0.612413
# color_intensity                        0.018732   0.199950      -0.055136
# hue                                   -0.273955   0.055398       0.433681
# od280/od315_of_diluted_wines          -0.276769   0.066004       0.699949
# proline                               -0.440597   0.393351       0.498115
#
#                               flavanoids  nonflavanoid_phenols  \
# alcohol                         0.236815             -0.155929
# malic_acid                     -0.411007              0.292977
# ash                             0.115077              0.186230
# alcalinity_of_ash              -0.351370              0.361922
# magnesium                       0.195784             -0.256294
# total_phenols                   0.864564             -0.449935
# flavanoids                      1.000000             -0.537900
# nonflavanoid_phenols           -0.537900              1.000000
# proanthocyanins                 0.652692             -0.365845
# color_intensity                -0.172379              0.139057
# hue                             0.543479             -0.262640
# od280/od315_of_diluted_wines    0.787194             -0.503270
# proline                         0.494193             -0.311385
#
#                               proanthocyanins  color_intensity       hue  \
# alcohol                              0.136698         0.546364 -0.071747
# malic_acid                          -0.220746         0.248985 -0.561296
# ash                                  0.009652         0.258887 -0.074667
# alcalinity_of_ash                   -0.197327         0.018732 -0.273955
# magnesium                            0.236441         0.199950  0.055398
# total_phenols                        0.612413        -0.055136  0.433681
# flavanoids                           0.652692        -0.172379  0.543479
# nonflavanoid_phenols                -0.365845         0.139057 -0.262640
# proanthocyanins                      1.000000        -0.025250  0.295544
# color_intensity                     -0.025250         1.000000 -0.521813
# hue                                  0.295544        -0.521813  1.000000
# od280/od315_of_diluted_wines         0.519067        -0.428815  0.565468
# proline                              0.330417         0.316100  0.236183
#
#                               od280/od315_of_diluted_wines   proline
# alcohol                                           0.072343  0.643720
# malic_acid                                       -0.368710 -0.192011
# ash                                               0.003911  0.223626
# alcalinity_of_ash                                -0.276769 -0.440597
# magnesium                                         0.066004  0.393351
# total_phenols                                     0.699949  0.498115
# flavanoids                                        0.787194  0.494193
# nonflavanoid_phenols                             -0.503270 -0.311385
# proanthocyanins                                   0.519067  0.330417
# color_intensity                                  -0.428815  0.316100
# hue                                               0.565468  0.236183
# od280/od315_of_diluted_wines                      1.000000  0.312761
# proline                                           0.312761  1.000000

# %% [markdown]
# We can see the correlation values, however making sense of the table by hand would take a lot of effort. Let's help ourselves with some formatting. Here we will use a [seaborn](https://seaborn.pydata.org/) library - it is a visualization tool based on the matplotlib. Usually you import seabron with an sns alias.

# %%
import seaborn as sns
#we are importing pyplot, just to change the size of the picture
import matplotlib.pyplot as plt

# %% [markdown]
# The correlation heatmap is drawn with the (who would've guessed) [heatmap()](https://seaborn.pydata.org/generated/seaborn.heatmap.html) function. This drawing can be specified in detail, but the simpliest use just takes the correlation values as the first argument of the function (here we also use the [colormap](https://matplotlib.org/stable/tutorials/colors/colormaps.html) argument, which is optional).

# %%
#this just sets the size of a picture
plt.figure(figsize=(10,8))
#here we draw the heatmap
sns.heatmap(wine_dataframe_normalized.corr(), cmap='YlOrRd')
# Out:
# <Axes: >

# %% [markdown]
# Notice, that the correlation values don't change if we do not apply normalization schema.

# %%
#this just sets the size of a picture
plt.figure(figsize=(10,8))
#here we draw the heatmap
sns.heatmap(wine_dataframe.corr(), cmap='YlOrRd')
# Out:
# <Axes: >

# %% [markdown]
# We observe a large number of strong correlations, but the features `total_phenols` and `flavanoids` stick out as very strongly correlated and thus are very likely redundant. Whenever we encounter two variables, which are very strongly correlated we can get rid of one of them. It is also useful to add the target values to the correlation analysis, we usually pick the feature, which has a stronger correlation with the target value.
#
# Let's go to the `supervised` feature scores. We can calculate the absolute values of the scores directly with use of the specific implementation ([chi2](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.chi2.html#sklearn.feature_selection.chi2), [f_classif](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.f_classif.html#sklearn.feature_selection.f_classif) ,[mutual_info_classif](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.mutual_info_classif.html#sklearn.feature_selection.mutual_info_classif), [f_regression](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.f_regression.html#sklearn.feature_selection.f_regression)). The function either returns the score for each feature or the set of scores and [p-values](https://en.wikipedia.org/wiki/P-value). We are not going to use p-values here.

# %%
from sklearn.feature_selection import f_regression, chi2, f_classif, mutual_info_classif

scores_regression, p_vals_reg = f_regression(wine_dataframe_normalized, wine.target)
scores_chi2, p_vals_chi2 = chi2(wine_dataframe_normalized, wine.target)
scores_anova, p_vals_anova = f_classif(wine_dataframe_normalized, wine.target)
scores_mi = mutual_info_classif(wine_dataframe_normalized, wine.target)
pd.DataFrame(scores_regression, wine.feature_names).plot(kind='barh', title='Regression')
pd.DataFrame(scores_chi2, wine.feature_names).plot(kind='barh', title='Chi squared')
pd.DataFrame(scores_anova, wine.feature_names).plot(kind='barh', title='ANOVA')
pd.DataFrame(scores_mi, wine.feature_names).plot(kind='barh', title='Mutual Information')
# Out:
# <Axes: title={'center': 'Mutual Information'}>

# %% [markdown]
# Now the scores can be used to get the best performing features. Here we can either use [SelectKBest](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html) class, optionally combined with SelectFpr, SelectFdr or SelectFwe functions, or the [GenericUnivariateSelect](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.GenericUnivariateSelect.html#sklearn.feature_selection.GenericUnivariateSelect) class. The FPR, FDR and FWE stand for False Positive Rate test, False Discovery Rate test and Family-Wise Error. Selecting a proper strategy is related to the task at hand. There are 4 possible strategies to choose from:
#  - KBest - simply choose the best performing features,
#  - False positive rate: is the probability of falsely rejecting the null hypothesis (https://en.wikipedia.org/wiki/False_positive_rate),
#  - False discovery rate: is the expected rate of false rejections from all discoveries, i.e. all rejected hypotheses (https://en.wikipedia.org/wiki/False_discovery_rate),
#  - Family wise error rate: is the probability of incurring at least one false positive among all discoveries (https://en.wikipedia.org/wiki/Family-wise_error_rate)
#
#  The KBest strategy is simple. The other strategies use an intermediate value calculated with a specific test (based on p-value and number of samples). We cannot say a priori which of the strategies is going to perform better.
#  - fpr chooses all features whose p-values are below a threshold, thus controlling the false positive rate of selection.
#  - fdr uses the Benjamini-Hochberg procedure to choose all features whose false discovery rate is below a threshold.
#  - fwe chooses all features whose p-values are below a threshold. The threshold is scaled by 1/numFeatures, thus controlling the family-wise error rate of selection.
#
#
#  Examples below.

# %%
from sklearn.feature_selection import GenericUnivariateSelect

gus_object = GenericUnivariateSelect(chi2, mode='k_best', param=5)

new_data = gus_object.fit_transform(wine_dataframe_normalized,wine.target)
new_dataframe = pd.DataFrame(new_data, columns=gus_object.get_feature_names_out())

# here we are picking the 1st and 2nd column from the dataframe and take just the values which correspond to each class of the wine
# we draw the samples from the first class in red, 2nd in green and 3rd in blue
# the easier it is to separate the samples, the better features we picked
# here we plot the second and third best features
plt.plot(new_dataframe[new_dataframe.columns[1]][wine.target==0],new_dataframe[new_dataframe.columns[2]][wine.target==0], 'r.')
plt.plot(new_dataframe[new_dataframe.columns[1]][wine.target==1],new_dataframe[new_dataframe.columns[2]][wine.target==1], 'g.')
plt.plot(new_dataframe[new_dataframe.columns[1]][wine.target==2],new_dataframe[new_dataframe.columns[2]][wine.target==2], 'b.')
plt.xlabel(gus_object.get_feature_names_out()[1])
plt.ylabel(gus_object.get_feature_names_out()[2])
plt.show()

new_dataframe[0:5]
# Out:
#     alcohol  flavanoids  color_intensity  od280/od315_of_diluted_wines  \
# 0  0.842105    0.573840         0.372014                      0.970696
# 1  0.571053    0.510549         0.264505                      0.780220
# 2  0.560526    0.611814         0.375427                      0.695971
# 3  0.878947    0.664557         0.556314                      0.798535
# 4  0.581579    0.495781         0.259386                      0.608059
#
#     proline
# 0  0.561341
# 1  0.550642
# 2  0.646933
# 3  0.857347
# 4  0.325963

# %%
from sklearn.feature_selection import SelectKBest, f_regression

skb_object = SelectKBest(f_regression, k=2)
wine_new = skb_object.fit_transform(wine_dataframe, wine.target)

feature1 = wine_new[:, 0]
feature2 = wine_new[:, 1]

#here we are drawing each sample with a different color
#the easier it is to separate the classes, the better is the performance of the picked features
plt.plot(feature1[wine.target==0], feature2[wine.target==0], 'r.')
plt.plot(feature1[wine.target==1], feature2[wine.target==1], 'g.')
plt.plot(feature1[wine.target==2], feature2[wine.target==2], 'b.')
plt.xlabel(skb_object.get_feature_names_out()[0])
plt.ylabel(skb_object.get_feature_names_out()[1])
plt.xlim([np.min(feature1)-1, np.max(feature1)+1])
plt.ylim([np.min(feature2)-1, np.max(feature2)+1])
plt.show()

# %% [markdown]
# ## Select features using linear regression and regularization

# %% [markdown]
# This method calculates usefulness of a feature on the basis of performed regression, or the classification process. The next example shows how to find the best 2 attributes to predict the type of wine using linear regression, where regression coefficients are regularized with L1. We will use the [SelectFromModel](http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectFromModel.html#sklearn.feature_selection.SelectFromModel) class. Regularization is available through [LassoCV](http://scikit-learn.org/stable/modules/linear_model.html#lasso) class. In the example, the classification process is performed once. Then, we iteratively compare the feature importances with various values for threshold. You can fiddle with various types of classifiers.

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Perceptron, LassoCV, SGDClassifier, RidgeClassifierCV

clf = Perceptron()
# clf = SGDClassifier(penalty='l1', loss='log_loss')
# clf = RidgeClassifierCV(cv=10)
# clf = LassoCV(cv=10)

sfm = SelectFromModel(clf, threshold=0.1)
sfm.fit(wine_dataframe_normalized, wine.target)
n_rows, n_features = sfm.transform(wine_dataframe_normalized).shape

while n_features > 2:
    sfm.threshold += 0.05
    wine_new = sfm.transform(wine_dataframe_normalized)
    n_rows, n_features = wine_new.shape
    
    feature_names = compress(wine_dataframe_normalized.columns, sfm.get_support())
    print(f'Threshold={sfm.threshold:.2f} Num features: {n_features}, {list(feature_names)}')

feature1 = wine_new[:, 0]
feature2 = wine_new[:, 1]

plt.plot(feature1[wine.target==0], feature2[wine.target==0], 'r.')
plt.plot(feature1[wine.target==1], feature2[wine.target==1], 'g.')
plt.plot(feature1[wine.target==2], feature2[wine.target==2], 'b.')
plt.xlabel(sfm.get_feature_names_out()[0])
plt.ylabel(sfm.get_feature_names_out()[1])
plt.ylim([np.min(feature2)-0.1, np.max(feature2)+0.1])
plt.xlim([np.min(feature1)-0.1, np.max(feature1)+0.1])
plt.show()
# Out:
# Threshold=0.15 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.20 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.25 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.30 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.35 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.40 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.45 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.50 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.55 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.60 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.65 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.70 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.75 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.80 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.85 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.90 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=0.95 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.00 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.05 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.10 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.15 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.20 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.25 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.30 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.35 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.40 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.45 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.50 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.55 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.60 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.65 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.70 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.75 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.80 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.85 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.90 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=1.95 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.00 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.05 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.10 Num features: 13, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.15 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.20 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.25 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.30 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.35 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.40 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.45 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.50 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.55 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.60 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.65 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.70 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.75 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.80 Num features: 12, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.85 Num features: 11, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.90 Num features: 11, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=2.95 Num features: 11, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.00 Num features: 11, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.05 Num features: 11, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.10 Num features: 11, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.15 Num features: 11, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.20 Num features: 11, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.25 Num features: 11, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.30 Num features: 11, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.35 Num features: 11, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.40 Num features: 11, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.45 Num features: 10, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.50 Num features: 10, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.55 Num features: 10, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.60 Num features: 10, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.65 Num features: 10, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.70 Num features: 10, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.75 Num features: 10, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.80 Num features: 10, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'total_phenols', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.85 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.90 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=3.95 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.00 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.05 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.10 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.15 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.20 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.25 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.30 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.35 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.40 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.45 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.50 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.55 Num features: 9, ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.60 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.65 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.70 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.75 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.80 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.85 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.90 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=4.95 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.00 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.05 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.10 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.15 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.20 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.25 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.30 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.35 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.40 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.45 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.50 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.55 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.60 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.65 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.70 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.75 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.80 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.85 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.90 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=5.95 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=6.00 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=6.05 Num features: 8, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Threshold=6.10 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.15 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.20 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.25 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.30 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.35 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.40 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.45 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.50 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.55 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.60 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.65 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.70 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.75 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.80 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.85 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.90 Num features: 7, ['alcohol', 'ash', 'alcalinity_of_ash', 'flavanoids', 'color_intensity', 'hue', 'proline']
# Threshold=6.95 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.00 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.05 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.10 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.15 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.20 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.25 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.30 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.35 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.40 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.45 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.50 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.55 Num features: 6, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'hue', 'proline']
# Threshold=7.60 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=7.65 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=7.70 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=7.75 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=7.80 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=7.85 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=7.90 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=7.95 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.00 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.05 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.10 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.15 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.20 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.25 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.30 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.35 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.40 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.45 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.50 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.55 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.60 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.65 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.70 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.75 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.80 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.85 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.90 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=8.95 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.00 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.05 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.10 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.15 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.20 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.25 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.30 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.35 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.40 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.45 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.50 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.55 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.60 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.65 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.70 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.75 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.80 Num features: 5, ['alcohol', 'ash', 'alcalinity_of_ash', 'color_intensity', 'proline']
# Threshold=9.85 Num features: 4, ['alcohol', 'ash', 'color_intensity', 'proline']
# Threshold=9.90 Num features: 4, ['alcohol', 'ash', 'color_intensity', 'proline']
# Threshold=9.95 Num features: 3, ['ash', 'color_intensity', 'proline']
# Threshold=10.00 Num features: 2, ['color_intensity', 'proline']

# %% [markdown]
# ## Recursive feature selection

# %% [markdown]
# The last example involves the [Recursive Feature Extraction](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html#sklearn.feature_selection.RFE) class to perform greedy selection of the features by evaluating each subset of features on the dataset using a classifer/regressor.

# %%
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor

# object which will be used to score the current selection
estimator = DecisionTreeRegressor()

# object performing recursive feature selection
selector = RFE(estimator, n_features_to_select=2, step=1)

selector = selector.fit(wine.data, wine.target)

boston_new = wine.data[:,selector.support_]

feature1 = boston_new[:, 0]
feature2 = boston_new[:, 1]

plt.plot(feature1[wine.target==0], feature2[wine.target==0], 'r.')
plt.plot(feature1[wine.target==1], feature2[wine.target==1], 'g.')
plt.plot(feature1[wine.target==2], feature2[wine.target==2], 'b.')
plt.xlabel(selector.get_feature_names_out()[0])
plt.ylabel(selector.get_feature_names_out()[1])
plt.ylim([np.min(feature2)-100, np.max(feature2)+100])
plt.xlim([np.min(feature1)-1, np.max(feature1)+1])
plt.show()

# %%
for (attr, rank, selected) in zip(wine.feature_names, selector.ranking_, selector.support_):
    print(f'{attr:>10}: rank={rank:<2} selected={selected}')
# Out:
#    alcohol: rank=4  selected=False
# malic_acid: rank=12 selected=False
#        ash: rank=11 selected=False
# alcalinity_of_ash: rank=10 selected=False
#  magnesium: rank=9  selected=False
# total_phenols: rank=8  selected=False
# flavanoids: rank=1  selected=True
# nonflavanoid_phenols: rank=7  selected=False
# proanthocyanins: rank=6  selected=False
# color_intensity: rank=2  selected=False
#        hue: rank=3  selected=False
# od280/od315_of_diluted_wines: rank=5  selected=False
#    proline: rank=1  selected=True

# %% [markdown]
# # Exercise/Homework
#
# Use the [sklearn.datasets.make_classification()](http://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html) function to create a synthetic dataset with 1000 instances and 20 features, where:
#
# * 5 features are information-rich
# * 5 features are superfluous
# * 5 features are duplicated
#
# Use any feature selection methods to select 5 most important attributes. Check if you can manage to discover these 5 truly information-rich features.

# %%
#Variant 1: creating dataset, min-max scaling, fidning clique by ourself, selecting k best features
from sklearn.datasets import make_classification
(data, target) = make_classification(n_samples= 1000, n_classes = 2, n_features=20, n_informative= 5, n_repeated=5, n_redundant=5, shuffle=False, random_state=969)

dataframe = pd.DataFrame(data, columns=[f"{i+1}" for i in range(len(data[0]))])
target = pd.DataFrame(target, columns = ["target"])

#Min Max scaling
scaler = MinMaxScaler()
scaler.fit(dataframe)
dataframe = pd.DataFrame(scaler.transform(dataframe), columns=dataframe.columns)

#Finding cliques
cliques = {}
for col1 in dataframe.corr():
    for col2 in dataframe.corr():
        if col1 != col2 and dataframe.corr()[col1][col2] >= 0.9:
            if (col1 in cliques):
                cliques[col1].append(col2)
            else:
                cliques[col1] = [col2]

cliques_pruned = []
processed = []
for clique in cliques:
    items = [clique] + cliques[clique]
    br = False
    for item in items:
        if (item in processed):
            br = True
    if br:
        continue
    processed += items
    cliques_pruned.append(items)

#Choosing a feature with highest correlation with target from every clique (in practice we delete duplicated columns)
to_delete = []
for clique in cliques_pruned:
    corrs = []
    for feature in clique:
        new_df = pd.concat([dataframe[feature], target], axis = 1)
        corrs.append(new_df.corr()["target"][feature])
    corrs = np.array(corrs)
    chosen = clique[corrs.argsort()[0]]
    to_delete.extend(list(set(clique) - set(chosen)))

to_preserve = [i for i in dataframe.columns if i not in to_delete]
new_dataframe = dataframe[to_preserve]

#Selecting k best features
gus_object = GenericUnivariateSelect(chi2, mode='k_best', param=5)
new_data = gus_object.fit_transform(new_dataframe, target)
new_dataframe = pd.DataFrame(new_data, columns=gus_object.get_feature_names_out())

plt.figure(figsize=(10,8))
sns.heatmap(new_dataframe.corr(), cmap='YlOrRd')
# Out:
# <Axes: >

# %%
#Variant 2: creating dataset, min-max scaling, selecting k best features
(data, target) = make_classification(n_samples= 1000, n_classes = 2, n_features=20, n_informative= 5, n_repeated=5, n_redundant=5, shuffle=False, random_state=969)

dataframe = pd.DataFrame(data, columns=[f"{i+1}" for i in range(len(data[0]))])
target = pd.DataFrame(target, columns = ["target"])

#Min Max scaling
scaler = MinMaxScaler()
scaler.fit(dataframe)
dataframe = pd.DataFrame(scaler.transform(dataframe), columns=dataframe.columns)

gus_object = GenericUnivariateSelect(chi2, mode='k_best', param=5)
new_data = gus_object.fit_transform(new_dataframe, target)
new_dataframe = pd.DataFrame(new_data, columns=gus_object.get_feature_names_out())

plt.figure(figsize=(10,8))
sns.heatmap(new_dataframe.corr(), cmap='YlOrRd')
# Out:
# <Axes: >

# %%
#Variant 3: creating dataset, selectng k best features
(data, target) = make_classification(n_samples= 1000, n_classes = 2, n_features=20, n_informative= 5, n_repeated=5, n_redundant=5, shuffle=False, random_state=969)

dataframe = pd.DataFrame(data, columns=[f"{i+1}" for i in range(len(data[0]))])
target = pd.DataFrame(target, columns = ["target"])

gus_object = GenericUnivariateSelect(chi2, mode='k_best', param=5)
new_data = gus_object.fit_transform(new_dataframe, target)
new_dataframe = pd.DataFrame(new_data, columns=gus_object.get_feature_names_out())

plt.figure(figsize=(10,8))
sns.heatmap(new_dataframe.corr(), cmap='YlOrRd')
# Out:
# <Axes: >

# %% [markdown]
# ### **Almost success!**
#
# Selected features: 1, 2, 3, 4, 9 (in all three variants)
#
# Informative features: 1, 2, 3, 4, 5
#
# If we would select 6 features (instead of 5), then all informative features would be chosen
