# %% [markdown]
# # Playing games!

# %% [markdown]
# In this assignment your task is to make computer play games. Of course, we limit ourselves to a very limited subset of games: two players, zero sum, perfect information, deterministic games. These properties may require some explanation:
#
# * *Two players* is pretty straightforward: there are exactly two players. Any less is a puzzle (see previous classes), any more is interesting (but out of scope).
# * *Zero sum* means that a win of one player is necessarly a loss of the other player. For example, if one player wins the game having 100 points, the other player must have exactly -100 points.
# * *Perfect information* means that there are no hidden variables in the game, like some cards kept in secret by players. Both players can see exactly the same thing.
# * *Deterministic* means that there is no randomness in the game, no dices, no decks of cards, etc.
#
# Each and every of these assumptions can be relaxed, yielding a more complex variant of the problem of playing games.

# %% [markdown]
# ## Game
#
# We begin by defining a general class `Game`, equipped with 7 functions:
#
# * `initial_state` returns a representation of an intial state of the game, e.g., an empty board and an information which player plays first. State is opaque to search algorithms, similarly as in the classes on Agents and A*.
# * `player` return the id of a player to make a move in the given `state`. Here we consistently use number 1 to represent the first player and 2 to represent the second player, but in general any two distict identifiers would suffice.
# * `actions` returns a list of valid moves in the given state. This corresponds to the list of available actions in previous classes.
# * `result` returns a new state after performing the given `action` in the given `state`. This is the transition model underpinning the game.
# * `is_terminal` returns `True` if the given `state` is a terminal node in the search tree, i.e., either one of the players won or it is a draw. This is a leaf in a search tree and no further actions can be executed.
# * `utility` can be called only for a terminal `state` and returns a numeric representation of how good this state is for the given `player`. Because we are considering zero-sum games it is always true that `utility(state, 1) = -utility(state, 2)`
# * `print_state` is a helper function to pretty-print the given `state` to the standard output. As the representation is opaque and possibly hard to read for a human, this little function will make our lives much easier further down the line.

# %%
class Game:
    @property
    def initial_state(self):
        ...
        return state
    
    def player(self, state):
        ...
        return playerno
        
    def actions(self, state):
        ...
        return actions
        
    def result(self, state, action):
        ...
        return new_state
        
    def is_terminal(self, state):
        ...
        return boolean
        
    def utility(self, state, player):
        ...        
        return number
        
    def print_state(self, state):
        ...

# %% [markdown]
# For convenience we define a simple function `opponent` that, given a player id, returns the id of the other player.

# %%
def opponent(player):    
    assert player in {1, 2}
    if player == 1:
        return 2
    else:
        return 1

# %% [markdown]
# ## Tic-Tac-Toe
#
# The first game we'll consider is *Tic-Tac-Toe* (*noughts and crosses*) in its bare minimum. For completeness, let me quote [Wikipedia](https://en.wikipedia.org/w/index.php?title=Tic-tac-toe&oldid=986503204) on rules:
#
# > Tic-tac-toe (American English), noughts and crosses (Commonwealth English), or Xs and Os, is a paper-and-pencil game for two players, X and O, who take turns marking the spaces in a 3×3 grid. The player who succeeds in placing three of their marks in a horizontal, vertical, or diagonal row is the winner. It is a solved game with a forced draw assuming best play from both players.

# %%
class TicTacToe(Game):    
    @property
    def initial_state(self):
        return (1, (0,)*9)
    
    def player(self, state):
        return state[0]
        
    def actions(self, state):
        return [i for i, v in enumerate(state[1]) if v == 0]
        
    def result(self, state, action):
        board = state[1]
        assert board[action] == 0
        assert state[0] in {1, 2}
        board = board[:action] + (state[0],) + board[action+1:]
        next_player = opponent(state[0])        
        return (next_player, board)
        
    def _has_line(self, state, player):
        board = state[1]
        for i in [0, 3, 6]:
            if board[i] == board[i+1] == board[i+2] == player:
                return True
        for i in [0, 1, 2]:
            if board[i] == board[i+3] == board[i+6] == player:
                return True
        if board[0] == board[3+1] == board[2*3+2] == player:
            return True
        if board[2] == board[3+1] == board[2*3] == player:
            return True
        return False
        
    def is_terminal(self, state):
        if all([v != 0 for v in state[1]]):
            return True
        return self._has_line(state, 1) or self._has_line(state, 2)
    
    def utility(self, state, player):
        assert player in {1, 2}
        mine = self._has_line(state, player)
        opponents = self._has_line(state, opponent(player))
        if mine and not opponents:
            return 1
        if not mine and opponents:
            return -1
        return 0    
    
    def print_state(self, state):
        print("Player making move", " OX"[state[0]])
        board = ["_OX"[v] for v in state[1]]
        print(*board[0:3])
        print(*board[3:6])
        print(*board[6:9])

# %% [markdown]
# The actions are represented by the number of field where to put a mark, using the following map:
#
# ```
# 0|1|2
# -----
# 3|4|5
# -----
# 6|7|8
# ```
#
# The cell below executes a sequence of actions that leads to a draw.

# %%
game = TicTacToe()
state = game.initial_state
game.print_state(state)

for action in [4,0,6,2,1,7,5,3,8]:
    assert action in game.actions(state)
    assert not game.is_terminal(state)
    state = game.result(state, action)
    game.print_state(state)
    
print("Reached terminal state?", game.is_terminal(state))
print("Utility for the 1st player", game.utility(state, 1))
print("Utility for the 2nd player", game.utility(state, 2))
# Out:
# Player making move O
# _ _ _
# _ _ _
# _ _ _
# Player making move X
# _ _ _
# _ O _
# _ _ _
# Player making move O
# X _ _
# _ O _
# _ _ _
# Player making move X
# X _ _
# _ O _
# O _ _
# Player making move O
# X _ X
# _ O _
# O _ _
# Player making move X
# X O X
# _ O _
# O _ _
# Player making move O
# X O X
# _ O _
# O X _
# Player making move X
# X O X
# _ O O
# O X _
# Player making move O
# X O X
# X O O
# O X _
# Player making move X
# X O X
# X O O
# O X O
# Reached terminal state? True
# Utility for the 1st player 0
# Utility for the 2nd player 0

# %% [markdown]
# Below, 2 plays suboptimally and loses.

# %%
game = TicTacToe()
state = game.initial_state
game.print_state(state)

for action in [4,0,6,2,1,8,7]:
    assert action in game.actions(state)
    assert not game.is_terminal(state)
    state = game.result(state, action)
    game.print_state(state)
    
print("Reached terminal state?", game.is_terminal(state))
print("Utility for the 1st player", game.utility(state, 1))
print("Utility for the 2nd player", game.utility(state, 2))
# Out:
# Player making move O
# _ _ _
# _ _ _
# _ _ _
# Player making move X
# _ _ _
# _ O _
# _ _ _
# Player making move O
# X _ _
# _ O _
# _ _ _
# Player making move X
# X _ _
# _ O _
# O _ _
# Player making move O
# X _ X
# _ O _
# O _ _
# Player making move X
# X O X
# _ O _
# O _ _
# Player making move O
# X O X
# _ O _
# O _ X
# Player making move X
# X O X
# _ O _
# O O X
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1

# %% [markdown]
# Finally, in the cell below 1 plays suboptimally and loses.

# %%
game = TicTacToe()
state = game.initial_state
game.print_state(state)

for action in [2,4,6,0,7,8]:
    assert action in game.actions(state)
    assert not game.is_terminal(state)
    state = game.result(state, action)
    game.print_state(state)
    
print("Reached terminal state?", game.is_terminal(state))
print("Utility for the 1st player", game.utility(state, 1))
print("Utility for the 2nd player", game.utility(state, 2))
# Out:
# Player making move O
# _ _ _
# _ _ _
# _ _ _
# Player making move X
# _ _ O
# _ _ _
# _ _ _
# Player making move O
# _ _ O
# _ X _
# _ _ _
# Player making move X
# _ _ O
# _ X _
# O _ _
# Player making move O
# X _ O
# _ X _
# O _ _
# Player making move X
# X _ O
# _ X _
# O O _
# Player making move O
# X _ O
# _ X _
# O O X
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1

# %% [markdown]
# ## A judge and a dummy

# %% [markdown]
# Lets define a common interface for a player: it is a callable (e.g., a function) receiving two arguments:
#
# 1. The definition of a game as an object of the class `Game`
# 2. A current state in which a move is to be made.
#
# The following function `dummy` follows this interface. It represents a player that always makes the first available move.

# %%
def dummy(game, state):
    return game.actions(state)[0]

# %% [markdown]
# To test players it is convenient to construct a general judge with three parameters:
#
# * `game` A definition of a game of type `Game`.
# * `player1` A callable following the interface described above representing the first player.
# * `player2` A callable following the interface described above representing the second player.

# %%
def judge(game: Game, player1, player2, display = True):    
    state = game.initial_state

    while not game.is_terminal(state):
        if game.player(state) == 1:
            action = player1(game, state)
        else:
            action = player2(game, state)
        if(display == True):
            game.print_state(state)
            print("Action:", action)
            print()
        state = game.result(state, action)

    game.print_state(state)
    print("Reached terminal state?", game.is_terminal(state))
    u1 = game.utility(state, 1)
    u2 = game.utility(state, 2)
    print("Utility for the 1st player", u1)
    print("Utility for the 2nd player", u2)
    if u1 > u2:
        print("Winner: 1st player")
    elif u1 < u2:
        print("Winner: 2nd player")
    else:
        print("Draw")

# %% [markdown]
# Lets see how well two dummies compete against each other in the game of Tic-Tac-Toe.

# %%
judge(TicTacToe(), dummy, dummy)
# Out:
# Player making move O
# _ _ _
# _ _ _
# _ _ _
# Action: 0
#
# Player making move X
# O _ _
# _ _ _
# _ _ _
# Action: 1
#
# Player making move O
# O X _
# _ _ _
# _ _ _
# Action: 2
#
# Player making move X
# O X O
# _ _ _
# _ _ _
# Action: 3
#
# Player making move O
# O X O
# X _ _
# _ _ _
# Action: 4
#
# Player making move X
# O X O
# X O _
# _ _ _
# Action: 5
#
# Player making move O
# O X O
# X O X
# _ _ _
# Action: 6
#
# Player making move X
# O X O
# X O X
# O _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player

# %% [markdown]
# ## Task 1: Minimax algorithm
#
# Complete the following cell with an implementation of the mini-max algorithm.
# The function should follow the interface for a player described above and return the best move to be made in the given `state` under the rules defined by the `game`.

# %%
def max_value(game: Game, state, player):
    if  (game.is_terminal(state)):
        return (game.utility(state, player), None)
    v = float('-inf')
    for a in game.actions(state):
        v2, a2 = min_value(game, game.result(state, a), player)
        if(v2 > v):
            v, move = v2, a
    return (v, move)

def min_value(game: Game, state, player):
    if  (game.is_terminal(state)):
        return (game.utility(state, player), None)
    v = float('inf')
    for a in game.actions(state):
        v2, a2 = max_value(game, game.result(state, a), player)
        if(v2 < v):
            v, move = v2, a
    return (v, move)

def minimax(game: Game, state):
    player = game.player(state)
    value, move = max_value(game, state, player)
    return move

# %% [markdown]
# Lets test your implementation against dummy and against itself. It should always win with dummy (dummy is deterministic and suboptimal) and it should draw with itself (Tic-Tac-Toe is a solved game and draw is the best outcome for optimal players).
# We prefix the calls to `judge` with `%time` to measure time spent in the call. This will be useful to compare the performance of minimax with alpha-beta.

# %%
# %time judge(TicTacToe(), minimax, dummy)
# Out:
# Player making move O
# _ _ _
# _ _ _
# _ _ _
# Action: 0
#
# Player making move X
# O _ _
# _ _ _
# _ _ _
# Action: 1
#
# Player making move O
# O X _
# _ _ _
# _ _ _
# Action: 3
#
# Player making move X
# O X _
# O _ _
# _ _ _
# Action: 2
#
# Player making move O
# O X X
# O _ _
# _ _ _
# Action: 4
#
# Player making move X
# O X X
# O O _
# _ _ _
# Action: 5
#
# Player making move O
# O X X
# O O X
# _ _ _
# Action: 6
#
# Player making move X
# O X X
# O O X
# O _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 3.22 s
# Wall time: 3.27 s

# %%
# %time judge(TicTacToe(), dummy, minimax)
# Out:
# Player making move O
# _ _ _
# _ _ _
# _ _ _
# Action: 0
#
# Player making move X
# O _ _
# _ _ _
# _ _ _
# Action: 4
#
# Player making move O
# O _ _
# _ X _
# _ _ _
# Action: 1
#
# Player making move X
# O O _
# _ X _
# _ _ _
# Action: 2
#
# Player making move O
# O O X
# _ X _
# _ _ _
# Action: 3
#
# Player making move X
# O O X
# O X _
# _ _ _
# Action: 6
#
# Player making move O
# O O X
# O X _
# X _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 375 ms
# Wall time: 382 ms

# %%
# %time judge(TicTacToe(), minimax, minimax)
# Out:
# Player making move O
# _ _ _
# _ _ _
# _ _ _
# Action: 0
#
# Player making move X
# O _ _
# _ _ _
# _ _ _
# Action: 4
#
# Player making move O
# O _ _
# _ X _
# _ _ _
# Action: 1
#
# Player making move X
# O O _
# _ X _
# _ _ _
# Action: 2
#
# Player making move O
# O O X
# _ X _
# _ _ _
# Action: 6
#
# Player making move X
# O O X
# _ X _
# O _ _
# Action: 3
#
# Player making move O
# O O X
# X X _
# O _ _
# Action: 5
#
# Player making move X
# O O X
# X X O
# O _ _
# Action: 7
#
# Player making move O
# O O X
# X X O
# O X _
# Action: 8
#
# Player making move X
# O O X
# X X O
# O X O
# Reached terminal state? True
# Utility for the 1st player 0
# Utility for the 2nd player 0
# Draw
# CPU times: total: 5.58 s
# Wall time: 5.6 s

# %% [markdown]
# ## Task 2: Alpha-beta
#
# Mini-max is an optimal solution, but not the most efficient. Complete the following cell of code implementing the alpha-beta algorithm.
# The function should follow the interface for a player described above and return the best move to be made in the given `state` under the rules defined by the `game`.

# %%
def max_value(game, state, player, alfa, beta):
    if (game.is_terminal(state)):
        return game.utility(state, player), None
    v = float('-inf')
    for a in game.actions(state):
        v2, a2 = min_value(game, game.result(state, a), player, alfa, beta)
        if (v2 > v):
            v, move = v2, a
            alfa = max(alfa, v)
        if(v>= beta):
            return v, move
    return v, move

def min_value(game, state, player, alfa, beta):
    if (game.is_terminal(state)):
        return game.utility(state, player), None
    v = float('inf')
    for a in game.actions(state):
        v2, a2 = max_value(game, game.result(state, a), player, alfa, beta)
        if (v2 < v):
            v, move = v2, a
            beta = min(beta, v)
        if(v<= alfa):
            return v, move
    return v, move

def alphabeta(game, state):
    player = game.player(state)
    value, move = max_value(game, state, player, float('-inf'), float('inf'))
    return move

# %% [markdown]
# Again, lets test your implementation against dummy and against itself. It should behave in exactly the same way as minimax, but be faster.

# %%
# %time judge(TicTacToe(), alphabeta, dummy)
# Out:
# Player making move O
# _ _ _
# _ _ _
# _ _ _
# Action: 0
#
# Player making move X
# O _ _
# _ _ _
# _ _ _
# Action: 1
#
# Player making move O
# O X _
# _ _ _
# _ _ _
# Action: 3
#
# Player making move X
# O X _
# O _ _
# _ _ _
# Action: 2
#
# Player making move O
# O X X
# O _ _
# _ _ _
# Action: 4
#
# Player making move X
# O X X
# O O _
# _ _ _
# Action: 5
#
# Player making move O
# O X X
# O O X
# _ _ _
# Action: 6
#
# Player making move X
# O X X
# O O X
# O _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 219 ms
# Wall time: 226 ms

# %%
# %time judge(TicTacToe(), dummy, alphabeta)
# Out:
# Player making move O
# _ _ _
# _ _ _
# _ _ _
# Action: 0
#
# Player making move X
# O _ _
# _ _ _
# _ _ _
# Action: 4
#
# Player making move O
# O _ _
# _ X _
# _ _ _
# Action: 1
#
# Player making move X
# O O _
# _ X _
# _ _ _
# Action: 2
#
# Player making move O
# O O X
# _ X _
# _ _ _
# Action: 3
#
# Player making move X
# O O X
# O X _
# _ _ _
# Action: 6
#
# Player making move O
# O O X
# O X _
# X _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 31.2 ms
# Wall time: 33.3 ms

# %%
# %time judge(TicTacToe(), alphabeta, alphabeta)
# Out:
# Player making move O
# _ _ _
# _ _ _
# _ _ _
# Action: 0
#
# Player making move X
# O _ _
# _ _ _
# _ _ _
# Action: 4
#
# Player making move O
# O _ _
# _ X _
# _ _ _
# Action: 1
#
# Player making move X
# O O _
# _ X _
# _ _ _
# Action: 2
#
# Player making move O
# O O X
# _ X _
# _ _ _
# Action: 6
#
# Player making move X
# O O X
# _ X _
# O _ _
# Action: 3
#
# Player making move O
# O O X
# X X _
# O _ _
# Action: 5
#
# Player making move X
# O O X
# X X O
# O _ _
# Action: 7
#
# Player making move O
# O O X
# X X O
# O X _
# Action: 8
#
# Player making move X
# O O X
# X X O
# O X O
# Reached terminal state? True
# Utility for the 1st player 0
# Utility for the 2nd player 0
# Draw
# CPU times: total: 328 ms
# Wall time: 315 ms

# %% [markdown]
# ## Migration

# %% [markdown]
# The following cell defines the rules for the game Migration. See https://www.di.fc.ul.pt/~jpn/gv/migration.htm for a complete description of rules. This implementation is somewhat more flexible: instead of using a board of fixed size, the size of a board is defined by the constructor parameter `n`. The first player that cannot move loses.

# %%
import math

class Migration:
    def __init__(self, n):
        self.n = n
    
    @property
    def initial_state(self):
        board = [[0]*self.n for _ in range(self.n)]
        k = math.ceil(self.n/2 - 1)
        for y in range(k):
            for x in range(y + 1, self.n - y - 1):
                board[x][y] = 1    
        for x in range(k):
            for y in range(x + 1, self.n - x - 1):
                board[self.n - x - 1][y] = 2
        board = tuple((tuple(row) for row in board))
        return (1, board)
    
    def player(self, state):
        return state[0]
    
    def _is_valid(self, x, y):
        return 0 <= x < self.n and 0 <= y < self.n
    
    def actions(self, state):
        board = state[1]
        player = self.player(state)
        opp = opponent(player)
        if player == 1:
            dx, dy = 0, 1
        else:
            assert player == 2
            dx, dy = -1, 0
        actions = []
        for x in range(self.n):
            nx = x + dx
            for y in range(self.n):
                ny = y + dy
                if board[x][y] == player and self._is_valid(nx, ny) and board[nx][ny] == 0:
                    actions.append((x, y, nx, ny))
        return actions
    
    def result(self, state, action):
        x, y, nx, ny = action
        player, board = state
        board = [list(row) for row in board]
        assert board[x][y] == player
        assert board[nx][ny] == 0
        board[x][y] = 0
        board[nx][ny] = player
        board = tuple((tuple(row) for row in board))
        return (opponent(player), board)
    
    def is_terminal(self, state):
        return len(self.actions(state)) == 0
        
    def utility(self, state, player):
        assert self.is_terminal(state)
        if self.player(state) == player:
            return -1
        else:
            return 1
        
    def print_state(self, state):
        print("Player making move", "_\u25CB\u25CF"[state[0]])
        for row in state[1]:
            print(*["_\u25CB\u25CF"[v] for v in row])
            
    def calculate_stones(self):
        n = self.n
        if (n%2 == 0):
            return (n/2 - 1)*n/2
        else:
            return (n//2)**2

# %% [markdown]
# Let's first see the initial state.

# %%
game = Migration(8)
state = game.initial_state
game.print_state(state)
# Out:
# Player making move ○
# _ _ _ _ _ _ _ _
# ○ _ _ _ _ _ _ _
# ○ ○ _ _ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ _ ● ● _ _ _
# ○ _ ● ● ● ● _ _
# _ ● ● ● ● ● ● _

# %% [markdown]
# Now, white makes a move.

# %%
move = game.actions(state)[0]
state = game.result(state, move)
game.print_state(state)
# Out:
# Player making move ●
# _ _ _ _ _ _ _ _
# _ ○ _ _ _ _ _ _
# ○ ○ _ _ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ _ ● ● _ _ _
# ○ _ ● ● ● ● _ _
# _ ● ● ● ● ● ● _

# %% [markdown]
# As this is a turn-taking game, now it is time for black.

# %%
move = game.actions(state)[5]
state = game.result(state, move)
game.print_state(state)
# Out:
# Player making move ○
# _ _ _ _ _ _ _ _
# _ ○ _ _ _ _ _ _
# ○ ○ _ _ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ _ ● ● _ _ _
# ○ _ ● ● ● ● ● _
# _ ● ● ● ● ● _ _

# %% [markdown]
# Let's see how well alpha-beta fares on a $4 \times 4$ board. The following cell should terminate within a few seconds.

# %%
judge(Migration(4), alphabeta, alphabeta)
# Out:
# Player making move ○
# _ _ _ _
# ○ _ _ _
# ○ _ _ _
# _ ● ● _
# Action: (1, 0, 1, 1)
#
# Player making move ●
# _ _ _ _
# _ ○ _ _
# ○ _ _ _
# _ ● ● _
# Action: (3, 1, 2, 1)
#
# Player making move ○
# _ _ _ _
# _ ○ _ _
# ○ ● _ _
# _ _ ● _
# Action: (1, 1, 1, 2)
#
# Player making move ●
# _ _ _ _
# _ _ ○ _
# ○ ● _ _
# _ _ ● _
# Action: (2, 1, 1, 1)
#
# Player making move ○
# _ _ _ _
# _ ● ○ _
# ○ _ _ _
# _ _ ● _
# Action: (1, 2, 1, 3)
#
# Player making move ●
# _ _ _ _
# _ ● _ ○
# ○ _ _ _
# _ _ ● _
# Action: (1, 1, 0, 1)
#
# Player making move ○
# _ ● _ _
# _ _ _ ○
# ○ _ _ _
# _ _ ● _
# Action: (2, 0, 2, 1)
#
# Player making move ●
# _ ● _ _
# _ _ _ ○
# _ ○ _ _
# _ _ ● _
# Action: (3, 2, 2, 2)
#
# Player making move ○
# _ ● _ _
# _ _ _ ○
# _ ○ ● _
# _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player

# %% [markdown]
# A $5 \times 5$ board is somewhat more challenging, but should still be within reach. The following cell should terminate within, say, 30 seconds at most.

# %%
# %time judge(Migration(5), alphabeta, alphabeta)
# Out:
# Player making move ○
# _ _ _ _ _
# ○ _ _ _ _
# ○ ○ _ _ _
# ○ _ ● _ _
# _ ● ● ● _
# Action: (2, 1, 2, 2)
#
# Player making move ●
# _ _ _ _ _
# ○ _ _ _ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ ● ● ● _
# Action: (4, 1, 3, 1)
#
# Player making move ○
# _ _ _ _ _
# ○ _ _ _ _
# ○ _ ○ _ _
# ○ ● ● _ _
# _ _ ● ● _
# Action: (1, 0, 1, 1)
#
# Player making move ●
# _ _ _ _ _
# _ ○ _ _ _
# ○ _ ○ _ _
# ○ ● ● _ _
# _ _ ● ● _
# Action: (3, 1, 2, 1)
#
# Player making move ○
# _ _ _ _ _
# _ ○ _ _ _
# ○ ● ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (1, 1, 1, 2)
#
# Player making move ●
# _ _ _ _ _
# _ _ ○ _ _
# ○ ● ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (2, 1, 1, 1)
#
# Player making move ○
# _ _ _ _ _
# _ ● ○ _ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (1, 2, 1, 3)
#
# Player making move ●
# _ _ _ _ _
# _ ● _ ○ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (1, 1, 0, 1)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ ○ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (1, 3, 1, 4)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ _ ○
# ○ _ ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (4, 3, 3, 3)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ _ ○
# ○ _ ○ _ _
# ○ _ ● ● _
# _ _ ● _ _
# Action: (2, 0, 2, 1)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ _ ○
# _ ○ ○ _ _
# ○ _ ● ● _
# _ _ ● _ _
# Action: (3, 3, 2, 3)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ _ ○
# _ ○ ○ ● _
# ○ _ ● _ _
# _ _ ● _ _
# Action: (3, 0, 3, 1)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ _ ○
# _ ○ ○ ● _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (2, 3, 1, 3)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ ● ○
# _ ○ ○ _ _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (2, 2, 2, 3)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ ● ○
# _ ○ _ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (1, 3, 0, 3)
#
# Player making move ○
# _ ● _ ● _
# _ _ _ _ ○
# _ ○ _ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (2, 1, 2, 2)
#
# Player making move ●
# _ ● _ ● _
# _ _ _ _ ○
# _ _ ○ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 16.5 s
# Wall time: 16.7 s

# %% [markdown]
# It goes without saying that alpha-beta should beat the dummy. Each of the following two cells should terminate within 30 seconds, and alpha-beta should be the winner.

# %%
# %time judge(Migration(5), alphabeta, dummy)
# Out:
# Player making move ○
# _ _ _ _ _
# ○ _ _ _ _
# ○ ○ _ _ _
# ○ _ ● _ _
# _ ● ● ● _
# Action: (2, 1, 2, 2)
#
# Player making move ●
# _ _ _ _ _
# ○ _ _ _ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ ● ● ● _
# Action: (4, 1, 3, 1)
#
# Player making move ○
# _ _ _ _ _
# ○ _ _ _ _
# ○ _ ○ _ _
# ○ ● ● _ _
# _ _ ● ● _
# Action: (1, 0, 1, 1)
#
# Player making move ●
# _ _ _ _ _
# _ ○ _ _ _
# ○ _ ○ _ _
# ○ ● ● _ _
# _ _ ● ● _
# Action: (3, 1, 2, 1)
#
# Player making move ○
# _ _ _ _ _
# _ ○ _ _ _
# ○ ● ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (1, 1, 1, 2)
#
# Player making move ●
# _ _ _ _ _
# _ _ ○ _ _
# ○ ● ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (2, 1, 1, 1)
#
# Player making move ○
# _ _ _ _ _
# _ ● ○ _ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (1, 2, 1, 3)
#
# Player making move ●
# _ _ _ _ _
# _ ● _ ○ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (1, 1, 0, 1)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ ○ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (1, 3, 1, 4)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ _ ○
# ○ _ ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (4, 3, 3, 3)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ _ ○
# ○ _ ○ _ _
# ○ _ ● ● _
# _ _ ● _ _
# Action: (2, 0, 2, 1)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ _ ○
# _ ○ ○ _ _
# ○ _ ● ● _
# _ _ ● _ _
# Action: (3, 3, 2, 3)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ _ ○
# _ ○ ○ ● _
# ○ _ ● _ _
# _ _ ● _ _
# Action: (3, 0, 3, 1)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ _ ○
# _ ○ ○ ● _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (2, 3, 1, 3)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ ● ○
# _ ○ ○ _ _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (2, 2, 2, 3)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ ● ○
# _ ○ _ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (1, 3, 0, 3)
#
# Player making move ○
# _ ● _ ● _
# _ _ _ _ ○
# _ ○ _ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (2, 1, 2, 2)
#
# Player making move ●
# _ ● _ ● _
# _ _ _ _ ○
# _ _ ○ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 12.8 s
# Wall time: 12.9 s

# %%
# %time judge(Migration(5), dummy, alphabeta)
# Out:
# Player making move ○
# _ _ _ _ _
# ○ _ _ _ _
# ○ ○ _ _ _
# ○ _ ● _ _
# _ ● ● ● _
# Action: (1, 0, 1, 1)
#
# Player making move ●
# _ _ _ _ _
# _ ○ _ _ _
# ○ ○ _ _ _
# ○ _ ● _ _
# _ ● ● ● _
# Action: (3, 2, 2, 2)
#
# Player making move ○
# _ _ _ _ _
# _ ○ _ _ _
# ○ ○ ● _ _
# ○ _ _ _ _
# _ ● ● ● _
# Action: (1, 1, 1, 2)
#
# Player making move ●
# _ _ _ _ _
# _ _ ○ _ _
# ○ ○ ● _ _
# ○ _ _ _ _
# _ ● ● ● _
# Action: (4, 1, 3, 1)
#
# Player making move ○
# _ _ _ _ _
# _ _ ○ _ _
# ○ ○ ● _ _
# ○ ● _ _ _
# _ _ ● ● _
# Action: (1, 2, 1, 3)
#
# Player making move ●
# _ _ _ _ _
# _ _ _ ○ _
# ○ ○ ● _ _
# ○ ● _ _ _
# _ _ ● ● _
# Action: (2, 2, 1, 2)
#
# Player making move ○
# _ _ _ _ _
# _ _ ● ○ _
# ○ ○ _ _ _
# ○ ● _ _ _
# _ _ ● ● _
# Action: (1, 3, 1, 4)
#
# Player making move ●
# _ _ _ _ _
# _ _ ● _ ○
# ○ ○ _ _ _
# ○ ● _ _ _
# _ _ ● ● _
# Action: (1, 2, 0, 2)
#
# Player making move ○
# _ _ ● _ _
# _ _ _ _ ○
# ○ ○ _ _ _
# ○ ● _ _ _
# _ _ ● ● _
# Action: (2, 1, 2, 2)
#
# Player making move ●
# _ _ ● _ _
# _ _ _ _ ○
# ○ _ ○ _ _
# ○ ● _ _ _
# _ _ ● ● _
# Action: (3, 1, 2, 1)
#
# Player making move ○
# _ _ ● _ _
# _ _ _ _ ○
# ○ ● ○ _ _
# ○ _ _ _ _
# _ _ ● ● _
# Action: (2, 2, 2, 3)
#
# Player making move ●
# _ _ ● _ _
# _ _ _ _ ○
# ○ ● _ ○ _
# ○ _ _ _ _
# _ _ ● ● _
# Action: (2, 1, 1, 1)
#
# Player making move ○
# _ _ ● _ _
# _ ● _ _ ○
# ○ _ _ ○ _
# ○ _ _ _ _
# _ _ ● ● _
# Action: (2, 0, 2, 1)
#
# Player making move ●
# _ _ ● _ _
# _ ● _ _ ○
# _ ○ _ ○ _
# ○ _ _ _ _
# _ _ ● ● _
# Action: (1, 1, 0, 1)
#
# Player making move ○
# _ ● ● _ _
# _ _ _ _ ○
# _ ○ _ ○ _
# ○ _ _ _ _
# _ _ ● ● _
# Action: (2, 1, 2, 2)
#
# Player making move ●
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ○ _
# ○ _ _ _ _
# _ _ ● ● _
# Action: (4, 3, 3, 3)
#
# Player making move ○
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ○ _
# ○ _ _ ● _
# _ _ ● _ _
# Action: (2, 3, 2, 4)
#
# Player making move ●
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ _ ○
# ○ _ _ ● _
# _ _ ● _ _
# Action: (3, 3, 2, 3)
#
# Player making move ○
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ● ○
# ○ _ _ _ _
# _ _ ● _ _
# Action: (3, 0, 3, 1)
#
# Player making move ●
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ● ○
# _ ○ _ _ _
# _ _ ● _ _
# Action: (4, 2, 3, 2)
#
# Player making move ○
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ● ○
# _ ○ ● _ _
# _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 7.53 s
# Wall time: 7.71 s

# %% [markdown]
# ## Task 3: Alpha-beta with limited depth and heuristic evaluation

# %% [markdown]
# Alpha-beta is a complete and optimal algorithm, but still too slow.
# In practice it is used as a heuristic algorithm: sometimes searching is terminated before reaching a terminal node and some heuristic evaluation of the reached non-terminal state is returned instead of the utility of a terminal state.
# How to evaluate non-terminal states and how to decide when to terminate search is an extremely rich topic.
#
# Complete the cells below:
#
# * Implement the function `evaluate` in `MigrationWithHeuristic` such that it returns some evaluation of the given `state` from the point of view of the given `player`. The more promising the state for the player, the higher value should be returned.
# * Implement the function `__call__` in `HeuristicAlphaBeta` such that it is an implementation of the alpha-beta algorithm, but should the recursion depth reach `self.max_depth` the heuristic evaluation should be returned instead of descending further in the game tree.
#
# Minimax and alpha-beta are game-agnostic and thus for them states are opaque. On the other hand `evaluate` is not game-agnostic, but it is also not (strictly speaking) a part of the rules of a game. Still, it needs to access the internals of the state and in the provided implementation of `Migration` the state is a 2-tuple:
#
# 1. The id of a player to make a move
# 2. The representation of a board as a tuple of tuples, forming an `self.n` $\times$ `self.n` array. Each element of this tuple of tuples is either:
#    * 0 - an empty cell
#    * 1 - a stone of player 1
#    * 2 - a stone of player 2

# %%
class MigrationWithHeuristic(Migration):
    def evaluate(self, state, player):
        if(self.player(state) == player):
            number = len(self.actions(state))
            enemy_state = (opponent(state[0]), state[1])
            number2 = len(self.actions(enemy_state))
        else:
            number2 = len(self.actions(state))
            enemy_state = (opponent(state[0]), state[1])
            number = len(self.actions(enemy_state)) 
        if(number == 0):
            return 0
        heur = (number - number2)/number #normalization so heur is in [-1, 1]
        return heur

# %%
class HeuristicAlphaBeta:
    def __init__(self, max_depth):
        self.max_depth = max_depth
    
    def max_value(self, game, state, player, alfa, beta, counter):
        if (game.is_terminal(state)):
            return game.utility(state, player), None
        v = float('-inf')
        for a in game.actions(state):
            if (counter >= self.max_depth):
                return game.evaluate(game.result(state, a), player), a
            v2, a2 = self.min_value(game, game.result(state, a), player, alfa, beta, counter+1)
            if (v2 > v):
                v, move = v2, a
                alfa = max(alfa, v)
            if(v>= beta):
                return v, move
        return v, move

    def min_value(self, game, state, player, alfa, beta, counter):
        if (game.is_terminal(state)):
            return game.utility(state, player), None
        v = float('inf')
        for a in game.actions(state):
            if (counter >= self.max_depth):
                return game.evaluate(game.result(state, a), player), a
            v2, a2 = self.max_value(game, game.result(state, a), player, alfa, beta, counter+1)
            if (v2 < v):
                v, move = v2, a
                beta = min(beta, v)
            if(v<= alfa):
                return v, move
        return v, move

    def __call__(self, game, state):
        player = game.player(state)
        value, best_move = self.max_value(game, state, player, float('-inf'), float('inf'), 0)
        return best_move

# %% [markdown]
# ## Task 4: Comparing alpha-beta and alpha-beta with heuristics

# %% [markdown]
# As you have seen $5\times 5$ board in this game is easy enough for alpha-beta, so we can use it to compare complete alpha-beta and alpha-beta with heuristics. Copy the next two cell a few times, and consider different depths for `HeuristicAlphaBeta`. Keep in mind that the game may be slightly unfair and thus you should always allow every player play in both positions before making conclusions. Afterwards, answer the question below the code cells.

# %%
# %time judge(MigrationWithHeuristic(5), HeuristicAlphaBeta(3), alphabeta)
# Out:
# Player making move ○
# _ _ _ _ _
# ○ _ _ _ _
# ○ ○ _ _ _
# ○ _ ● _ _
# _ ● ● ● _
# Action: (2, 1, 2, 2)
#
# Player making move ●
# _ _ _ _ _
# ○ _ _ _ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ ● ● ● _
# Action: (4, 1, 3, 1)
#
# Player making move ○
# _ _ _ _ _
# ○ _ _ _ _
# ○ _ ○ _ _
# ○ ● ● _ _
# _ _ ● ● _
# Action: (1, 0, 1, 1)
#
# Player making move ●
# _ _ _ _ _
# _ ○ _ _ _
# ○ _ ○ _ _
# ○ ● ● _ _
# _ _ ● ● _
# Action: (3, 1, 2, 1)
#
# Player making move ○
# _ _ _ _ _
# _ ○ _ _ _
# ○ ● ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (1, 1, 1, 2)
#
# Player making move ●
# _ _ _ _ _
# _ _ ○ _ _
# ○ ● ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (2, 1, 1, 1)
#
# Player making move ○
# _ _ _ _ _
# _ ● ○ _ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (1, 2, 1, 3)
#
# Player making move ●
# _ _ _ _ _
# _ ● _ ○ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (1, 1, 0, 1)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ ○ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (2, 0, 2, 1)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ ○ _
# _ ○ ○ _ _
# ○ _ ● _ _
# _ _ ● ● _
# Action: (4, 3, 3, 3)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ ○ _
# _ ○ ○ _ _
# ○ _ ● ● _
# _ _ ● _ _
# Action: (2, 2, 2, 3)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ ○ _
# _ ○ _ ○ _
# ○ _ ● ● _
# _ _ ● _ _
# Action: (3, 2, 2, 2)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ ○ _
# _ ○ ● ○ _
# ○ _ _ ● _
# _ _ ● _ _
# Action: (1, 3, 1, 4)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ _ ○
# _ ○ ● ○ _
# ○ _ _ ● _
# _ _ ● _ _
# Action: (2, 2, 1, 2)
#
# Player making move ○
# _ ● _ _ _
# _ _ ● _ ○
# _ ○ _ ○ _
# ○ _ _ ● _
# _ _ ● _ _
# Action: (2, 1, 2, 2)
#
# Player making move ●
# _ ● _ _ _
# _ _ ● _ ○
# _ _ ○ ○ _
# ○ _ _ ● _
# _ _ ● _ _
# Action: (1, 2, 0, 2)
#
# Player making move ○
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ○ _
# ○ _ _ ● _
# _ _ ● _ _
# Action: (2, 3, 2, 4)
#
# Player making move ●
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ _ ○
# ○ _ _ ● _
# _ _ ● _ _
# Action: (3, 3, 2, 3)
#
# Player making move ○
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ● ○
# ○ _ _ _ _
# _ _ ● _ _
# Action: (3, 0, 3, 1)
#
# Player making move ●
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ● ○
# _ ○ _ _ _
# _ _ ● _ _
# Action: (4, 2, 3, 2)
#
# Player making move ○
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ● ○
# _ ○ ● _ _
# _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 4.11 s
# Wall time: 4.15 s

# %%
# %time judge(MigrationWithHeuristic(5), alphabeta, HeuristicAlphaBeta(5))
# Out:
# Player making move ○
# _ _ _ _ _
# ○ _ _ _ _
# ○ ○ _ _ _
# ○ _ ● _ _
# _ ● ● ● _
# Action: (2, 1, 2, 2)
#
# Player making move ●
# _ _ _ _ _
# ○ _ _ _ _
# ○ _ ○ _ _
# ○ _ ● _ _
# _ ● ● ● _
# Action: (4, 1, 3, 1)
#
# Player making move ○
# _ _ _ _ _
# ○ _ _ _ _
# ○ _ ○ _ _
# ○ ● ● _ _
# _ _ ● ● _
# Action: (1, 0, 1, 1)
#
# Player making move ●
# _ _ _ _ _
# _ ○ _ _ _
# ○ _ ○ _ _
# ○ ● ● _ _
# _ _ ● ● _
# Action: (4, 3, 3, 3)
#
# Player making move ○
# _ _ _ _ _
# _ ○ _ _ _
# ○ _ ○ _ _
# ○ ● ● ● _
# _ _ ● _ _
# Action: (1, 1, 1, 2)
#
# Player making move ●
# _ _ _ _ _
# _ _ ○ _ _
# ○ _ ○ _ _
# ○ ● ● ● _
# _ _ ● _ _
# Action: (3, 3, 2, 3)
#
# Player making move ○
# _ _ _ _ _
# _ _ ○ _ _
# ○ _ ○ ● _
# ○ ● ● _ _
# _ _ ● _ _
# Action: (1, 2, 1, 3)
#
# Player making move ●
# _ _ _ _ _
# _ _ _ ○ _
# ○ _ ○ ● _
# ○ ● ● _ _
# _ _ ● _ _
# Action: (3, 1, 2, 1)
#
# Player making move ○
# _ _ _ _ _
# _ _ _ ○ _
# ○ ● ○ ● _
# ○ _ ● _ _
# _ _ ● _ _
# Action: (3, 0, 3, 1)
#
# Player making move ●
# _ _ _ _ _
# _ _ _ ○ _
# ○ ● ○ ● _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (2, 1, 1, 1)
#
# Player making move ○
# _ _ _ _ _
# _ ● _ ○ _
# ○ _ ○ ● _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (1, 3, 1, 4)
#
# Player making move ●
# _ _ _ _ _
# _ ● _ _ ○
# ○ _ ○ ● _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (1, 1, 0, 1)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ _ ○
# ○ _ ○ ● _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (2, 0, 2, 1)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ _ ○
# _ ○ ○ ● _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (2, 3, 1, 3)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ ● ○
# _ ○ ○ _ _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (2, 2, 2, 3)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ ● ○
# _ ○ _ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Action: (3, 2, 2, 2)
#
# Player making move ○
# _ ● _ _ _
# _ _ _ ● ○
# _ ○ ● ○ _
# _ ○ _ _ _
# _ _ ● _ _
# Action: (3, 1, 3, 2)
#
# Player making move ●
# _ ● _ _ _
# _ _ _ ● ○
# _ ○ ● ○ _
# _ _ ○ _ _
# _ _ ● _ _
# Action: (1, 3, 0, 3)
#
# Player making move ○
# _ ● _ ● _
# _ _ _ _ ○
# _ ○ ● ○ _
# _ _ ○ _ _
# _ _ ● _ _
# Action: (2, 3, 2, 4)
#
# Player making move ●
# _ ● _ ● _
# _ _ _ _ ○
# _ ○ ● _ ○
# _ _ ○ _ _
# _ _ ● _ _
# Action: (2, 2, 1, 2)
#
# Player making move ○
# _ ● _ ● _
# _ _ ● _ ○
# _ ○ _ _ ○
# _ _ ○ _ _
# _ _ ● _ _
# Action: (2, 1, 2, 2)
#
# Player making move ●
# _ ● _ ● _
# _ _ ● _ ○
# _ _ ○ _ ○
# _ _ ○ _ _
# _ _ ● _ _
# Action: (1, 2, 0, 2)
#
# Player making move ○
# _ ● ● ● _
# _ _ _ _ ○
# _ _ ○ _ ○
# _ _ ○ _ _
# _ _ ● _ _
# Action: (2, 2, 2, 3)
#
# Player making move ●
# _ ● ● ● _
# _ _ _ _ ○
# _ _ _ ○ ○
# _ _ ○ _ _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 12.6 s
# Wall time: 12.6 s

# %%
for i in range(1, 10):
    print("Depth:", i)
    # %time judge(MigrationWithHeuristic(5), alphabeta, HeuristicAlphaBeta(i), False)
    print("_________________________________________________________")

for i in range(1, 10):
    print("Depth:", i)
    # %time judge(MigrationWithHeuristic(5), HeuristicAlphaBeta(i), alphabeta, False)
    print("_________________________________________________________")
# Out:
# Depth: 1
# Player making move ●
# _ ● ● ● _
# _ _ _ _ ○
# _ _ _ ○ ○
# _ _ ○ _ _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 8.84 s
# Wall time: 9.29 s
# _________________________________________________________
# Depth: 2
# Player making move ●
# _ ● _ ● _
# _ _ _ _ ○
# _ _ ○ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 11.8 s
# Wall time: 12.2 s
# _________________________________________________________
# Depth: 3
# Player making move ●
# _ ● ● ● _
# _ _ _ _ ○
# _ _ _ ○ ○
# _ _ ○ _ _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 7.97 s
# Wall time: 8.15 s
# _________________________________________________________
# Depth: 4
# Player making move ●
# _ ● _ ● _
# _ _ _ _ ○
# _ _ ○ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 7.56 s
# Wall time: 7.73 s
# _________________________________________________________
# Depth: 5
# Player making move ●
# _ ● _ ● _
# _ _ _ _ ○
# _ _ ○ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 8.14 s
# Wall time: 8.7 s
# _________________________________________________________
# Depth: 6
# Player making move ●
# _ ● _ ● _
# _ _ _ _ ○
# _ _ ○ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 7.17 s
# Wall time: 7.31 s
# _________________________________________________________
# Depth: 7
# Player making move ●
# _ ● _ ● _
# _ _ _ _ ○
# _ _ ○ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 8.14 s
# Wall time: 8.46 s
# _________________________________________________________
# Depth: 8
# Player making move ●
# _ ● _ ● _
# _ _ _ _ ○
# _ _ ○ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 7.92 s
# Wall time: 8.23 s
# _________________________________________________________
# Depth: 9
# Player making move ●
# _ ● _ ● _
# _ _ _ _ ○
# _ _ ○ ○ _
# _ ○ ● _ _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 8.25 s
# Wall time: 8.48 s
# _________________________________________________________
# Depth: 1
# Player making move ○
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ● ○
# _ ○ ● _ _
# _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 2.58 s
# Wall time: 2.67 s
# _________________________________________________________
# Depth: 2
# Player making move ○
# _ _ ● ● _
# _ ● _ _ ○
# _ _ _ ○ ○
# _ ○ ● _ _
# _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 1.58 s
# Wall time: 1.61 s
# _________________________________________________________
# Depth: 3
# Player making move ○
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ● ○
# _ ○ ● _ _
# _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 2.66 s
# Wall time: 2.79 s
# _________________________________________________________
# Depth: 4
# Player making move ○
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ● ○
# _ ○ ● _ _
# _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 2.73 s
# Wall time: 2.86 s
# _________________________________________________________
# Depth: 5
# Player making move ○
# _ ● ● _ _
# _ _ _ _ ○
# _ _ ○ ● ○
# _ ○ ● _ _
# _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 2.62 s
# Wall time: 2.68 s
# _________________________________________________________
# Depth: 6
# Player making move ●
# _ ● _ _ _
# _ _ ○ _ _
# _ ○ ● ○ _
# _ _ ○ ● _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 2.64 s
# Wall time: 2.8 s
# _________________________________________________________
# Depth: 7
# Player making move ○
# _ _ ● ● _
# _ ● _ _ ○
# _ _ _ ○ ○
# _ ○ ● _ _
# _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 1.33 s
# Wall time: 1.43 s
# _________________________________________________________
# Depth: 8
# Player making move ●
# _ ● ● _ _
# _ _ _ _ ○
# _ ○ _ ○ _
# _ _ ○ ● _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 2.27 s
# Wall time: 2.3 s
# _________________________________________________________
# Depth: 9
# Player making move ●
# _ ● ● _ _
# _ _ _ _ ○
# _ ○ _ ○ _
# _ _ ○ ● _
# _ _ ● _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 2.33 s
# Wall time: 2.37 s
# _________________________________________________________

# %% [markdown]
# **Summarize your experiments briefly (what depths did you consider, how long did it took; if you've changed any other parameters from the defaults, specify the new values). Is complete alpha-beta always better than its heuristics variant, or do they become equally good at some point? Why do you think is that?**

# %% [markdown]
# I considered a for loop comparing alphabeta with HeuristicAlphaBeta with depth varying from 1 to 9 (including) and opposite case.
#
# a) Time of computation
# In first case time was between 7 to 12 seconds and was bigger from second case - 1 to 3 seconds (first move was done by alphabeta, second by HeuristicAlphaBeta so alphabeta had more possibilities to move and needed more function calls than in opposite case each turn)
#
# However in both - first and second case time of computations was below time of computation of alphabeta vs alphabeta which was 20 seconds.
#
# b) Result:
# In first case alphabeta beat heuristic version 9:0. However, because game is a bit unfair we should also check case heuristic version vs alphabeta - here the result was 6:3 for alphabeta (Heuristic version won for depth 6, 8 and 9). In total alphabeta won 15:3 with its heuristic version.
#
# Here we need to have a compromise between time and result each algorithm achieves. Algorithm with heuristic evaluation works faster, but makes errors and performs (much) worse (especially when depth is small) than normal alphabeta.
# I think the best compromise possible to achieve is to have HeuristicAlphaBeta but with properly set depth (around 7 or 8 and more). It will perform similarly to alphabeta and will do it faster.

# %% [markdown]
# ## Task 5: Comparing different depths of alpha-beta with heuristics

# %% [markdown]
# Now, let's switch to the original version of the game on the $8\times 8$ board. Your heuristics alpha-beta should be capable of playing it against itself within a reasonable time limit (say, 30 seconds per game). Similarly to the previous task, copy the following cell multiple times and fiddle with the depths. Then, answer the question below the code cells.

# %%
# %time judge(MigrationWithHeuristic(8), HeuristicAlphaBeta(5), HeuristicAlphaBeta(5))
# Out:
# Player making move ○
# _ _ _ _ _ _ _ _
# ○ _ _ _ _ _ _ _
# ○ ○ _ _ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ _ ● ● _ _ _
# ○ _ ● ● ● ● _ _
# _ ● ● ● ● ● ● _
# Action: (2, 1, 2, 2)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# ○ _ _ _ _ _ _ _
# ○ _ ○ _ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ _ ● ● _ _ _
# ○ _ ● ● ● ● _ _
# _ ● ● ● ● ● ● _
# Action: (5, 3, 4, 3)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# ○ _ _ _ _ _ _ _
# ○ _ ○ _ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ ○ ● _ _ _ _
# ○ ○ _ _ ● _ _ _
# ○ _ ● ● ● ● _ _
# _ ● ● ● ● ● ● _
# Action: (2, 2, 2, 3)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# ○ _ _ _ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ ○ ● _ _ _ _
# ○ ○ _ _ ● _ _ _
# ○ _ ● ● ● ● _ _
# _ ● ● ● ● ● ● _
# Action: (6, 2, 5, 2)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# ○ _ _ _ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ ○ _ _ _ _ _
# ○ ○ ○ ● _ _ _ _
# ○ ○ ● _ ● _ _ _
# ○ _ _ ● ● ● _ _
# _ ● ● ● ● ● ● _
# Action: (3, 2, 3, 3)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# ○ _ _ _ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ _ ○ _ _ _ _
# ○ ○ ○ ● _ _ _ _
# ○ ○ ● _ ● _ _ _
# ○ _ _ ● ● ● _ _
# _ ● ● ● ● ● ● _
# Action: (5, 4, 4, 4)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# ○ _ _ _ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ _ ○ _ _ _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● _ _ _ _ _
# ○ _ _ ● ● ● _ _
# _ ● ● ● ● ● ● _
# Action: (3, 3, 3, 4)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# ○ _ _ _ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ _ _ ○ _ _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● _ _ _ _ _
# ○ _ _ ● ● ● _ _
# _ ● ● ● ● ● ● _
# Action: (6, 5, 5, 5)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# ○ _ _ _ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ _ _ ○ _ _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● _ _ ● _ _
# ○ _ _ ● ● _ _ _
# _ ● ● ● ● ● ● _
# Action: (6, 0, 6, 1)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# ○ _ _ _ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ _ _ ○ _ _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● _ _ ● _ _
# _ ○ _ ● ● _ _ _
# _ ● ● ● ● ● ● _
# Action: (5, 5, 4, 5)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# ○ _ _ _ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ _ _ ○ _ _ _
# ○ ○ ○ ● ● ● _ _
# ○ ○ ● _ _ _ _ _
# _ ○ _ ● ● _ _ _
# _ ● ● ● ● ● ● _
# Action: (1, 0, 1, 1)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ ○ _ _ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ _ _ ○ _ _ _
# ○ ○ ○ ● ● ● _ _
# ○ ○ ● _ _ _ _ _
# _ ○ _ ● ● _ _ _
# _ ● ● ● ● ● ● _
# Action: (4, 5, 3, 5)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ ○ _ _ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ _ _ ○ ● _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● _ _ _ _ _
# _ ○ _ ● ● _ _ _
# _ ● ● ● ● ● ● _
# Action: (1, 1, 1, 2)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ ○ _ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ _ _ ○ ● _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● _ _ _ _ _
# _ ○ _ ● ● _ _ _
# _ ● ● ● ● ● ● _
# Action: (6, 3, 5, 3)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ ○ _ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ _ _ ○ ● _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● ● _ _ _ _
# _ ○ _ _ ● _ _ _
# _ ● ● ● ● ● ● _
# Action: (1, 2, 1, 3)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ ○ _ _ _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ _ _ ○ ● _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● ● _ _ _ _
# _ ○ _ _ ● _ _ _
# _ ● ● ● ● ● ● _
# Action: (3, 5, 2, 5)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ ○ _ _ _ _
# ○ _ _ ○ _ ● _ _
# ○ ○ _ _ ○ _ _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● ● _ _ _ _
# _ ○ _ _ ● _ _ _
# _ ● ● ● ● ● ● _
# Action: (1, 3, 1, 4)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ _ _ _
# ○ _ _ ○ _ ● _ _
# ○ ○ _ _ ○ _ _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● ● _ _ _ _
# _ ○ _ _ ● _ _ _
# _ ● ● ● ● ● ● _
# Action: (2, 5, 1, 5)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# ○ _ _ ○ _ _ _ _
# ○ ○ _ _ ○ _ _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● ● _ _ _ _
# _ ○ _ _ ● _ _ _
# _ ● ● ● ● ● ● _
# Action: (3, 1, 3, 2)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# ○ _ _ ○ _ _ _ _
# ○ _ ○ _ ○ _ _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● ● _ _ _ _
# _ ○ _ _ ● _ _ _
# _ ● ● ● ● ● ● _
# Action: (6, 4, 5, 4)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# ○ _ _ ○ _ _ _ _
# ○ _ ○ _ ○ _ _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● ● ● _ _ _
# _ ○ _ _ _ _ _ _
# _ ● ● ● ● ● ● _
# Action: (2, 0, 2, 1)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ ○ _ ○ _ _ _ _
# ○ _ ○ _ ○ _ _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● ● ● _ _ _
# _ ○ _ _ _ _ _ _
# _ ● ● ● ● ● ● _
# Action: (4, 3, 3, 3)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ ○ _ ○ _ _ _ _
# ○ _ ○ ● ○ _ _ _
# ○ ○ ○ _ ● _ _ _
# ○ ○ ● ● ● _ _ _
# _ ○ _ _ _ _ _ _
# _ ● ● ● ● ● ● _
# Action: (4, 2, 4, 3)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ ○ _ ○ _ _ _ _
# ○ _ ○ ● ○ _ _ _
# ○ ○ _ ○ ● _ _ _
# ○ ○ ● ● ● _ _ _
# _ ○ _ _ _ _ _ _
# _ ● ● ● ● ● ● _
# Action: (5, 2, 4, 2)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ ○ _ ○ _ _ _ _
# ○ _ ○ ● ○ _ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● _ _ _
# _ ○ _ _ _ _ _ _
# _ ● ● ● ● ● ● _
# Action: (6, 1, 6, 2)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ ○ _ ○ _ _ _ _
# ○ _ ○ ● ○ _ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● _ _ _
# _ _ ○ _ _ _ _ _
# _ ● ● ● ● ● ● _
# Action: (7, 3, 6, 3)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ ○ _ ○ _ _ _ _
# ○ _ ○ ● ○ _ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● _ _ _
# _ _ ○ ● _ _ _ _
# _ ● ● _ ● ● ● _
# Action: (2, 1, 2, 2)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ○ _ _ _ _
# ○ _ ○ ● ○ _ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● _ _ _
# _ _ ○ ● _ _ _ _
# _ ● ● _ ● ● ● _
# Action: (7, 5, 6, 5)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ○ _ _ _ _
# ○ _ ○ ● ○ _ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● _ _ _
# _ _ ○ ● _ ● _ _
# _ ● ● _ ● _ ● _
# Action: (2, 3, 2, 4)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ _ ○ _ _ _
# ○ _ ○ ● ○ _ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● _ _ _
# _ _ ○ ● _ ● _ _
# _ ● ● _ ● _ ● _
# Action: (3, 3, 2, 3)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● ○ _ _ _
# ○ _ ○ _ ○ _ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● _ _ _
# _ _ ○ ● _ ● _ _
# _ ● ● _ ● _ ● _
# Action: (2, 4, 2, 5)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ ○ _ _
# ○ _ ○ _ ○ _ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● _ _ _
# _ _ ○ ● _ ● _ _
# _ ● ● _ ● _ ● _
# Action: (6, 5, 5, 5)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ ○ _ _
# ○ _ ○ _ ○ _ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● ● _ _
# _ _ ○ ● _ _ _ _
# _ ● ● _ ● _ ● _
# Action: (2, 5, 2, 6)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ ○ _
# ○ _ ○ _ ○ _ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● ● _ _
# _ _ ○ ● _ _ _ _
# _ ● ● _ ● _ ● _
# Action: (7, 6, 6, 6)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ ○ _
# ○ _ ○ _ ○ _ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● ● _ _
# _ _ ○ ● _ _ ● _
# _ ● ● _ ● _ _ _
# Action: (3, 4, 3, 5)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ ○ _
# ○ _ ○ _ _ ○ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● ● _ _
# _ _ ○ ● _ _ ● _
# _ ● ● _ ● _ _ _
# Action: (6, 6, 5, 6)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ ○ _
# ○ _ ○ _ _ ○ _ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● ● ● _
# _ _ ○ ● _ _ _ _
# _ ● ● _ ● _ _ _
# Action: (3, 5, 3, 6)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ ○ _
# ○ _ ○ _ _ _ ○ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● ● ● _
# _ _ ○ ● _ _ _ _
# _ ● ● _ ● _ _ _
# Action: (7, 1, 6, 1)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ ○ _
# ○ _ ○ _ _ _ ○ _
# ○ ○ ● ○ ● _ _ _
# ○ ○ _ ● ● ● ● _
# _ ● ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (5, 1, 5, 2)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ ○ _
# ○ _ ○ _ _ _ ○ _
# ○ ○ ● ○ ● _ _ _
# ○ _ ○ ● ● ● ● _
# _ ● ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (6, 1, 5, 1)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ ○ _
# ○ _ ○ _ _ _ ○ _
# ○ ○ ● ○ ● _ _ _
# ○ ● ○ ● ● ● ● _
# _ _ ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (3, 0, 3, 1)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ ○ _
# _ ○ ○ _ _ _ ○ _
# ○ ○ ● ○ ● _ _ _
# ○ ● ○ ● ● ● ● _
# _ _ ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (4, 4, 3, 4)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ ○ _
# _ ○ ○ _ ● _ ○ _
# ○ ○ ● ○ _ _ _ _
# ○ ● ○ ● ● ● ● _
# _ _ ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (4, 3, 4, 4)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ ○ _
# _ ○ ○ _ ● _ ○ _
# ○ ○ ● _ ○ _ _ _
# ○ ● ○ ● ● ● ● _
# _ _ ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (5, 5, 4, 5)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ ○ _
# _ ○ ○ _ ● _ ○ _
# ○ ○ ● _ ○ ● _ _
# ○ ● ○ ● ● _ ● _
# _ _ ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (2, 6, 2, 7)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ _ ○
# _ ○ ○ _ ● _ ○ _
# ○ ○ ● _ ○ ● _ _
# ○ ● ○ ● ● _ ● _
# _ _ ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (4, 5, 3, 5)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ _ ○
# _ ○ ○ _ ● ● ○ _
# ○ ○ ● _ ○ _ _ _
# ○ ● ○ ● ● _ ● _
# _ _ ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (3, 2, 3, 3)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ _ _ ○
# _ ○ _ ○ ● ● ○ _
# ○ ○ ● _ ○ _ _ _
# ○ ● ○ ● ● _ ● _
# _ _ ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (3, 5, 2, 5)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ ● _ ○
# _ ○ _ ○ ● _ ○ _
# ○ ○ ● _ ○ _ _ _
# ○ ● ○ ● ● _ ● _
# _ _ ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (3, 1, 3, 2)
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ ● _ ○
# _ _ ○ ○ ● _ ○ _
# ○ ○ ● _ ○ _ _ _
# ○ ● ○ ● ● _ ● _
# _ _ ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (5, 3, 4, 3)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ ● _ ○
# _ _ ○ ○ ● _ ○ _
# ○ ○ ● ● ○ _ _ _
# ○ ● ○ _ ● _ ● _
# _ _ ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (3, 6, 3, 7)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ○ _ _ _
# ○ ● ○ _ ● _ ● _
# _ _ ○ ● _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (6, 3, 5, 3)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ○ _ _ _
# ○ ● ○ ● ● _ ● _
# _ _ ○ _ _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (4, 4, 4, 5)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● _ ○ _ _
# ○ ● ○ ● ● _ ● _
# _ _ ○ _ _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (5, 4, 4, 4)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● ○ _ _
# ○ ● ○ ● _ _ ● _
# _ _ ○ _ _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (4, 5, 4, 6)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ ○ _
# ○ ● ○ ● _ _ ● _
# _ _ ○ _ _ _ _ _
# _ _ ● _ ● _ _ _
# Action: (7, 4, 6, 4)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ ○ _
# ○ ● ○ ● _ _ ● _
# _ _ ○ _ ● _ _ _
# _ _ ● _ _ _ _ _
# Action: (6, 2, 6, 3)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ ○ ● _ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ ○ _
# ○ ● ○ ● _ _ ● _
# _ _ _ ○ ● _ _ _
# _ _ ● _ _ _ _ _
# Action: (2, 3, 1, 3)
#
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ ● ○ ● _ _
# _ _ ○ _ _ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ ○ _
# ○ ● ○ ● _ _ ● _
# _ _ _ ○ ● _ _ _
# _ _ ● _ _ _ _ _
# Action: (2, 2, 2, 3)
#
# Player making move ●
# _ _ _ _ _ _ _ _
# _ _ _ ● ○ ● _ _
# _ _ _ ○ _ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ ○ _
# ○ ● ○ ● _ _ ● _
# _ _ _ ○ ● _ _ _
# _ _ ● _ _ _ _ _
# Action: (1, 3, 0, 3)
#
# Player making move ○
# _ _ _ ● _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ _ ○ _ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ ○ _
# ○ ● ○ ● _ _ ● _
# _ _ _ ○ ● _ _ _
# _ _ ● _ _ _ _ _
# Action: (2, 3, 2, 4)
#
# Player making move ●
# _ _ _ ● _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ ○ _
# ○ ● ○ ● _ _ ● _
# _ _ _ ○ ● _ _ _
# _ _ ● _ _ _ _ _
# Action: (7, 2, 6, 2)
#
# Player making move ○
# _ _ _ ● _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ ○ _
# ○ ● ○ ● _ _ ● _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (4, 6, 4, 7)
#
# Player making move ●
# _ _ _ ● _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ _ ○
# ○ ● ○ ● _ _ ● _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (1, 5, 0, 5)
#
# Player making move ○
# _ _ _ ● _ ● _ _
# _ _ _ _ ○ _ _ _
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ _ ○
# ○ ● ○ ● _ _ ● _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (1, 4, 1, 5)
#
# Player making move ●
# _ _ _ ● _ ● _ _
# _ _ _ _ _ ○ _ _
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ _ ○
# ○ ● ○ ● _ _ ● _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (5, 6, 4, 6)
#
# Player making move ○
# _ _ _ ● _ ● _ _
# _ _ _ _ _ ○ _ _
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ ● ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (1, 5, 1, 6)
#
# Player making move ●
# _ _ _ ● _ ● _ _
# _ _ _ _ _ _ ○ _
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ● _ ● ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (4, 6, 3, 6)
#
# Player making move ○
# _ _ _ ● _ ● _ _
# _ _ _ _ _ _ ○ _
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ ● ○
# ○ ○ ● ● ● _ _ ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (1, 6, 1, 7)
#
# Player making move ●
# _ _ _ ● _ ● _ _
# _ _ _ _ _ _ _ ○
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ ● ○
# ○ ○ ● ● ● _ _ ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (2, 5, 1, 5)
#
# Player making move ○
# _ _ _ ● _ ● _ _
# _ _ _ _ _ ● _ ○
# _ _ _ _ ○ _ _ ○
# _ _ ○ ○ ● _ ● ○
# ○ ○ ● ● ● _ _ ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (2, 4, 2, 5)
#
# Player making move ●
# _ _ _ ● _ ● _ _
# _ _ _ _ _ ● _ ○
# _ _ _ _ _ ○ _ ○
# _ _ ○ ○ ● _ ● ○
# ○ ○ ● ● ● _ _ ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (3, 4, 2, 4)
#
# Player making move ○
# _ _ _ ● _ ● _ _
# _ _ _ _ _ ● _ ○
# _ _ _ _ ● ○ _ ○
# _ _ ○ ○ _ _ ● ○
# ○ ○ ● ● ● _ _ ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (2, 5, 2, 6)
#
# Player making move ●
# _ _ _ ● _ ● _ _
# _ _ _ _ _ ● _ ○
# _ _ _ _ ● _ ○ ○
# _ _ ○ ○ _ _ ● ○
# ○ ○ ● ● ● _ _ ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (2, 4, 1, 4)
#
# Player making move ○
# _ _ _ ● _ ● _ _
# _ _ _ _ ● ● _ ○
# _ _ _ _ _ _ ○ ○
# _ _ ○ ○ _ _ ● ○
# ○ ○ ● ● ● _ _ ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (3, 3, 3, 4)
#
# Player making move ●
# _ _ _ ● _ ● _ _
# _ _ _ _ ● ● _ ○
# _ _ _ _ _ _ ○ ○
# _ _ ○ _ ○ _ ● ○
# ○ ○ ● ● ● _ _ ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (4, 3, 3, 3)
#
# Player making move ○
# _ _ _ ● _ ● _ _
# _ _ _ _ ● ● _ ○
# _ _ _ _ _ _ ○ ○
# _ _ ○ ● ○ _ ● ○
# ○ ○ ● _ ● _ _ ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (3, 4, 3, 5)
#
# Player making move ●
# _ _ _ ● _ ● _ _
# _ _ _ _ ● ● _ ○
# _ _ _ _ _ _ ○ ○
# _ _ ○ ● _ ○ ● ○
# ○ ○ ● _ ● _ _ ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Action: (1, 4, 0, 4)
#
# Player making move ○
# _ _ _ ● ● ● _ _
# _ _ _ _ _ ● _ ○
# _ _ _ _ _ _ ○ ○
# _ _ ○ ● _ ○ ● ○
# ○ ○ ● _ ● _ _ ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 4.34 s
# Wall time: 4.47 s

# %%
for i in range(1, 10):
    print("Depth:", i)
    # %time judge(MigrationWithHeuristic(8), HeuristicAlphaBeta(4), HeuristicAlphaBeta(i), False)
    print("_________________________________________________________")

for i in range(1, 10):
    print("Depth:", i)
    # %time judge(MigrationWithHeuristic(8), HeuristicAlphaBeta(i), HeuristicAlphaBeta(4), False)
    print("_________________________________________________________")

for i in range(1, 10):
    print("Depth:", i)
    # %time judge(MigrationWithHeuristic(8), HeuristicAlphaBeta(i), HeuristicAlphaBeta(i), False)
    print("_________________________________________________________")
# Out:
# Depth: 1
# Player making move ●
# _ _ _ ● _ ● _ _
# _ _ _ _ _ ○ _ _
# _ _ _ ○ ○ _ _ _
# _ _ ○ ○ ● _ ○ _
# ○ _ _ ○ ● ○ ● _
# _ ○ ○ ● ● ● _ _
# ○ ● ● ● _ _ _ _
# _ _ ● _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 453 ms
# Wall time: 441 ms
# _________________________________________________________
# Depth: 2
# Player making move ●
# _ _ _ ● _ ● _ _
# _ _ _ _ _ ○ _ _
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ ○ _
# _ ○ ○ ○ ● _ ● _
# ○ _ ○ ● ● _ _ _
# _ ○ ● ● _ _ _ _
# _ ● ● _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 438 ms
# Wall time: 451 ms
# _________________________________________________________
# Depth: 3
# Player making move ○
# _ _ _ _ ● _ _ _
# _ _ _ _ _ _ _ ○
# _ _ ○ ● _ _ _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ● ● ○ ● _ _
# ○ ○ ● _ ● ● ● _
# ○ ● _ _ _ _ _ _
# _ _ _ ● _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 766 ms
# Wall time: 773 ms
# _________________________________________________________
# Depth: 4
# Player making move ○
# _ _ _ ● _ ● _ _
# _ _ _ _ _ _ _ ○
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ○ ● _ _ ● _
# ○ ○ ● _ ● _ _ _
# _ ○ ● ● _ _ _ _
# _ ● _ _ ● _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 781 ms
# Wall time: 823 ms
# _________________________________________________________
# Depth: 5
# Player making move ○
# _ _ _ _ ● ● _ _
# _ _ _ _ _ _ _ ○
# _ ○ ○ ● _ _ _ _
# _ _ ● ● ● ○ ○ ○
# ○ ○ ● _ _ _ _ ○
# ○ ● _ _ ○ ● ● _
# _ _ ○ ● ● _ _ _
# _ _ _ _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 4.91 s
# Wall time: 5.07 s
# _________________________________________________________
# Depth: 6
# Player making move ○
# _ _ _ _ _ ● _ _
# _ _ _ _ _ _ _ ○
# _ _ _ _ ○ ○ ● _
# _ _ ○ ○ ○ ● _ _
# ○ ○ ○ ● ● _ _ _
# ○ ○ ● ● ● _ _ _
# ○ ● _ _ _ _ _ _
# _ _ ● ● ● _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 3.28 s
# Wall time: 3.37 s
# _________________________________________________________
# Depth: 7
# Player making move ○
# _ _ _ _ ● ● _ _
# _ _ _ _ _ ● _ ○
# _ _ _ _ _ _ ○ ○
# _ _ _ ○ ● ○ ● ○
# ○ ○ ○ ● _ _ _ _
# ○ ○ ● ● _ _ _ _
# ○ ● ● ● ● _ _ _
# _ _ _ _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 10.1 s
# Wall time: 10.3 s
# _________________________________________________________
# Depth: 8
# Player making move ○
# _ _ _ _ ● _ _ _
# _ _ _ _ _ _ _ ○
# _ _ _ ○ ○ ● _ _
# _ _ ○ ○ ● _ _ ○
# ○ ○ ○ ● ● _ _ _
# ○ ● ○ ● _ ● ● _
# _ ○ ● ● _ _ _ _
# _ _ ● _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 40.2 s
# Wall time: 40.8 s
# _________________________________________________________
# Depth: 9
# Player making move ○
# _ _ _ ● ● ● _ _
# _ _ _ _ ● ● _ ○
# _ _ _ _ _ _ ○ ○
# _ _ ○ ● _ _ ○ ○
# ○ ○ ○ ● _ _ _ _
# _ ○ ● _ _ _ _ ○
# ○ ● ● _ ● _ ● _
# _ _ _ _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 3min 49s
# Wall time: 3min 51s
# _________________________________________________________
# Depth: 1
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ ○ ● _ _ _
# _ _ ○ ○ ● _ _ _
# _ _ _ ○ ○ ● _ ○
# _ ○ ○ ○ ● ● ● _
# ○ ○ ● ● _ _ _ _
# _ ○ ● ● _ _ _ _
# _ ● _ ● _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 422 ms
# Wall time: 417 ms
# _________________________________________________________
# Depth: 2
# Player making move ○
# _ _ _ ● _ ● _ _
# _ _ _ _ _ _ _ ○
# _ _ _ ○ ● _ _ ○
# _ _ _ ○ ● ○ ● ○
# ○ ○ ○ ● _ ● _ _
# ○ ○ ● _ _ _ _ _
# _ ○ ● ● _ _ _ _
# _ ● _ _ ● _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 391 ms
# Wall time: 390 ms
# _________________________________________________________
# Depth: 3
# Player making move ○
# _ _ _ _ _ _ ● _
# _ _ _ _ _ _ _ ○
# _ _ _ ○ ○ ● _ _
# _ _ ○ ○ ● _ _ ○
# ○ ○ ○ ● ● ● _ _
# ○ ○ ● ● _ _ _ _
# ○ ● _ _ _ _ _ _
# _ _ ● ● ● _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 406 ms
# Wall time: 417 ms
# _________________________________________________________
# Depth: 4
# Player making move ○
# _ _ _ ● _ ● _ _
# _ _ _ _ _ _ _ ○
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ○ ● _ _ ● _
# ○ ○ ● _ ● _ _ _
# _ ○ ● ● _ _ _ _
# _ ● _ _ ● _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 703 ms
# Wall time: 749 ms
# _________________________________________________________
# Depth: 5
# Player making move ●
# _ _ ● ● ● ● ● _
# _ _ _ _ _ ● _ ○
# _ _ _ _ _ _ ○ ○
# _ _ _ ○ ○ _ _ ○
# _ ○ ○ ● ● ○ _ _
# _ ○ ● ● ○ _ _ _
# _ ● _ _ ● _ _ ○
# _ _ _ _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 3.09 s
# Wall time: 3.24 s
# _________________________________________________________
# Depth: 6
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ ○
# _ _ ○ ● _ _ _ ○
# _ ○ ○ ● ○ ● _ _
# ○ ○ ○ ● ● ● ● _
# ○ ● _ ○ ● _ _ _
# _ ○ ● _ _ _ _ _
# _ _ ● _ ● _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 3.62 s
# Wall time: 3.76 s
# _________________________________________________________
# Depth: 7
# Player making move ●
# _ ● ● ● ● ● ● _
# _ _ _ ● _ ● _ ○
# _ _ _ _ _ _ ○ ○
# _ _ _ _ ○ _ ○ ○
# _ _ ○ _ ○ _ _ ○
# _ ○ ● ○ ● _ _ _
# _ _ _ ● ● _ _ ○
# _ _ _ _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 19.2 s
# Wall time: 20 s
# _________________________________________________________
# Depth: 8
# Player making move ○
# _ _ ● ● _ _ _ _
# _ _ _ _ _ _ _ ○
# _ _ _ ○ ● _ _ ○
# _ _ ○ ● ○ ● _ ○
# ○ ○ ● _ ○ ● ● _
# _ ○ ○ ● ● _ _ _
# _ _ _ ○ ● _ _ _
# _ ● _ _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 57.1 s
# Wall time: 57.4 s
# _________________________________________________________
# Depth: 9
# Player making move ●
# _ _ ● ● _ ● _ _
# _ _ ● ● _ ● _ ○
# _ _ _ _ _ _ ○ ○
# _ _ _ _ _ ○ ○ ○
# ○ ○ _ _ ○ _ ● _
# ○ _ _ ○ ● _ _ _
# _ ○ _ ● ● _ _ _
# _ ● _ _ ● _ _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 1min 38s
# Wall time: 1min 39s
# _________________________________________________________
# Depth: 1
# Player making move ○
# _ _ _ _ _ ● _ _
# _ _ _ _ _ _ _ ○
# _ _ ○ ● _ ○ ● _
# _ _ ○ ○ ○ ● _ _
# _ ○ ○ ○ ● _ _ _
# _ ○ ○ ● ● _ _ _
# ○ ● ● ● ● _ _ _
# _ _ ● _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 15.6 ms
# Wall time: 17 ms
# _________________________________________________________
# Depth: 2
# Player making move ○
# _ _ _ _ ● ● _ _
# _ _ _ _ _ _ _ ○
# _ ○ ○ ● _ _ _ _
# _ _ ○ ○ ● _ _ ○
# _ _ ○ ○ ● ○ ● _
# _ ○ ○ ● _ ● _ _
# ○ ● ● _ _ _ _ _
# _ _ ● ● _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 78.1 ms
# Wall time: 84 ms
# _________________________________________________________
# Depth: 3
# Player making move ○
# _ _ _ _ _ _ _ _
# _ _ _ _ ○ ● _ _
# _ _ _ ○ ● ● _ ○
# _ _ ○ ○ ● _ ● ○
# ○ ○ ○ ● ● _ _ _
# _ ○ ○ ● _ _ _ _
# _ ○ ● _ _ _ _ _
# _ ● ● ● _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 266 ms
# Wall time: 259 ms
# _________________________________________________________
# Depth: 4
# Player making move ○
# _ _ _ ● _ ● _ _
# _ _ _ _ _ _ _ ○
# _ _ _ _ ○ ● _ ○
# _ _ ○ ○ ● _ _ ○
# ○ ○ ○ ● _ _ ● _
# ○ ○ ● _ ● _ _ _
# _ ○ ● ● _ _ _ _
# _ ● _ _ ● _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 703 ms
# Wall time: 714 ms
# _________________________________________________________
# Depth: 5
# Player making move ○
# _ _ _ ● ● ● _ _
# _ _ _ _ _ ● _ ○
# _ _ _ _ _ _ ○ ○
# _ _ ○ ● _ ○ ● ○
# ○ ○ ● _ ● _ _ ○
# ○ ● ○ ● _ _ _ _
# _ _ ● ○ ● _ _ _
# _ _ _ _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 4.19 s
# Wall time: 4.29 s
# _________________________________________________________
# Depth: 6
# Player making move ○
# _ _ _ ● _ ● _ _
# _ _ _ _ _ _ _ ○
# _ _ _ _ _ ○ ● ○
# _ ○ ○ ● _ ● _ ○
# ○ ● ○ ○ ● _ _ _
# _ ○ ● ○ ● _ _ _
# _ ○ ● ● _ _ _ _
# _ _ _ _ ● _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 11.6 s
# Wall time: 11.9 s
# _________________________________________________________
# Depth: 7
# Player making move ●
# _ _ ● ● _ ● _ _
# _ _ _ _ _ ● _ ○
# _ _ _ _ _ ○ _ ○
# _ _ ○ ○ _ _ ○ _
# _ ○ ○ ● ○ _ ● _
# ○ _ ○ ● ● _ _ _
# _ ○ ● _ ● _ _ _
# _ ● _ _ ● _ _ _
# Reached terminal state? True
# Utility for the 1st player 1
# Utility for the 2nd player -1
# Winner: 1st player
# CPU times: total: 28.1 s
# Wall time: 28.3 s
# _________________________________________________________
# Depth: 8
# Player making move ○
# _ _ _ _ ● ● _ _
# _ _ _ _ _ _ _ ○
# _ _ ○ ● _ _ _ ○
# _ _ _ ○ ○ ○ ● _
# ○ ○ ● ● ○ ● _ _
# _ ○ ● ○ ● _ _ _
# _ ● ○ ● ● _ _ _
# _ _ _ _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 1min
# Wall time: 1min
# _________________________________________________________
# Depth: 9
# Player making move ○
# _ ● _ ● ● ● _ _
# _ _ _ _ ● _ _ ○
# _ _ _ _ ● _ ○ ○
# _ _ _ _ ○ ○ ● ○
# _ ○ ○ ● _ _ _ ○
# _ ○ ○ ● _ _ _ _
# _ ○ ● _ _ ● _ _
# _ _ ● _ _ _ _ _
# Reached terminal state? True
# Utility for the 1st player -1
# Utility for the 2nd player 1
# Winner: 2nd player
# CPU times: total: 4min 7s
# Wall time: 4min 9s
# _________________________________________________________

# %% [markdown]
# **Summarize your experiments briefly (what depths did you consider, how long did it took; if you've changed any other parameters from the defaults, specify the new values). Is the alpha-beta searching deeper always better than the shallower one? What about games when two alpha-betas of equal depth play against each other? Is there a clear pattern (e.g., the first/second player always wins), or does it change between different depths and/or differnt executions? Try to come up with an explanation for all the observations.**

# %% [markdown]
# I considered three cases:
# a) fixed depth 4 vs depth varying from 1 to 9
# b) depth varying from 1 to 9 vs fixed depth 4
# c) equal depths varying from 1 to 9
#
# No other parameters were changed
#
# Actually it is hard to find any pattern
# a) In first case depth four won twice and here computations took some time
# b) In second case depth 4 won 6 times and computations took less time
# c) In third case first HeuristicAlphaBeta with depth varying from 1 to 9 and won once and computations took the most time
#
# Results don't change between different executions (no randomness)
#
# The only pattern I can see is that in most cases second player is more likely to win.
# Second observation is obvious - bigger depth takes more time.
#
# For me reasoning standing behind the results is that this game is too complex (for sure more complex than Tic Tac Toe) to predict any results based on depth of Heuristic thus it is hard to see any pattern related to depth. We can only predict that second player is more probable to win (1 move to do less)
